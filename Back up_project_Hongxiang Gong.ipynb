# %% [markdown]
# # CME538 - Introduction to Data Science
#  Toronto Bike Share**

# %% [markdown]
# # Setup Notebook

# %%
# Import 3rd party libraries
import os
import json
import numpy as np
import datetime as dt
import codecs
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from io import StringIO
from fuzzywuzzy import fuzz

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/brucehaoyuli/opt/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Get Station Data
# Get the up to date bikeshare station information from `https://tor.publicbikesystem.net`.

# %%
response = requests.get('https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information')
bikeshare_stations = pd.DataFrame(json.loads(response.content)['data']['stations'])[['station_id', 'name', 'lat', 'lon', 'capacity']].astype({'station_id': 'int',})
bikeshare_stations = bikeshare_stations.rename(columns={'station_id': 'Station Id', 
                                                        'name': 'Station Name'})

# View DataFrame
bikeshare_stations.head(15)
# Out:
#     Station Id                                Station Name        lat  \
# 0         7000                Fort York  Blvd / Capreol Ct  43.639832
# 1         7001                   Wellesley Station Green P  43.664964
# 2         7002                  St. George St / Bloor St W  43.667333
# 3         7003                    Madison Ave / Bloor St W  43.667158
# 4         7004                     University Ave / Elm St  43.656518
# 5         7005                         King St W / York St  43.648001
# 6         7006             Bay St / College St (East Side)  43.660439
# 7         7007                       College St / Huron St  43.658148
# 8         7008            Wellesley St / Queen's Park Cres  43.663376
# 9         7009                       King St E / Jarvis St  43.650325
# 10        7010                     King St W / Spadina Ave  43.645323
# 11        7012     Elizabeth St / Edward St (Bus Terminal)  43.656026
# 12        7014  Sherbourne St / Carlton St (Allan Gardens)  43.663102
# 13        7015              King St W / Bay St (West Side)  43.648520
# 14        7016     Bay St / Queens Quay W (Ferry Terminal)  43.640978
#
#           lon  capacity
# 0  -79.395954        35
# 1  -79.383550        26
# 2  -79.399429        19
# 3  -79.402761        15
# 4  -79.389099        11
# 5  -79.383177        19
# 6  -79.385525        19
# 7  -79.398167        19
# 8  -79.392125        19
# 9  -79.372287        25
# 10 -79.395003        19
# 11 -79.385327        15
# 12 -79.373181        17
# 13 -79.380576        39
# 14 -79.376785        23

# %%
bikeshare_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 655 entries, 0 to 654
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Station Id    655 non-null    int64
#  1   Station Name  655 non-null    object
#  2   lat           655 non-null    float64
#  3   lon           655 non-null    float64
#  4   capacity      655 non-null    int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 25.7+ KB

# %%
bikeshare_stations.nunique()
# Out:
# Station Id      655
# Station Name    655
# lat             653
# lon             654
# capacity         37
# dtype: int64

# %% [markdown]
# The station dataframe has no missing/duplicated station name or id.

# %%
# Write bikeshare station dataframe to a csv file
path_stations = os.path.join(os.path.abspath(os.getcwd()), 'data', 'stations')
bikeshare_stations.to_csv(os.path.join(path_stations, 'bikeshare_stations.csv'))

# %% [markdown]
# ## Weather Data

# %% [markdown]
# ### Load Weather Data

# %%
# Set weather data path
path_weather = os.path.join(os.path.abspath(os.getcwd()), 'data', 'weather')

# Get weather file names
weather_filenames = [filename for filename in os.listdir(path_weather) if 'climate' in filename]

# Print file names
print(weather_filenames[0:5])
# Out:
# ['en_climate_hourly_ON_6158359_11-2021_P1H.csv', 'en_climate_hourly_ON_6158359_08-2022_P1H.csv', 'en_climate_hourly_ON_6158359_03-2021_P1H.csv', 'en_climate_hourly_ON_6158359_04-2021_P1H.csv', 'en_climate_hourly_ON_6158359_04-2017_P1H.csv']

# %%
# Create a dictionary where key:value pairs correspond to the file name and DataFrame respectively
weather_data = {filename: pd.read_csv(os.path.join(path_weather, filename)) for filename in weather_filenames}

# %%
weather_rename = {
    'Date/Time (LST)' : 'Date/Time',
    'Time (LST)' : 'Time',
}

for filename in weather_filenames:
    weather_data[filename].rename(columns=weather_rename, inplace=True)

# %%
# Import weather
weather = pd.concat([weather_data[filename] for filename in weather_filenames], ignore_index=True)

# View DataFrame
weather.head()
# Out:
#    Longitude (x)  Latitude (y)         Station Name  Climate ID  \
# 0          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 1          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 2          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 3          -79.4         43.63  TORONTO CITY CENTRE     6158359
# 4          -79.4         43.63  TORONTO CITY CENTRE     6158359
#
#           Date/Time  Year  Month  Day   Time  Temp (°C)  ... Wind Spd Flag  \
# 0  2021-11-01 00:00  2021     11    1  00:00        9.3  ...           NaN
# 1  2021-11-01 01:00  2021     11    1  01:00        8.5  ...           NaN
# 2  2021-11-01 02:00  2021     11    1  02:00        8.0  ...           NaN
# 3  2021-11-01 03:00  2021     11    1  03:00        7.7  ...           NaN
# 4  2021-11-01 04:00  2021     11    1  04:00        7.0  ...           NaN
#
#    Visibility (km) Visibility Flag  Stn Press (kPa) Stn Press Flag  Hmdx  \
# 0             16.1             NaN           100.10            NaN   NaN
# 1             16.1             NaN           100.21            NaN   NaN
# 2             16.1             NaN           100.29            NaN   NaN
# 3             16.1             NaN           100.41            NaN   NaN
# 4             16.1             NaN           100.50            NaN   NaN
#
#    Hmdx Flag  Wind Chill Wind Chill Flag  Weather
# 0        NaN         NaN             NaN      NaN
# 1        NaN         NaN             NaN      NaN
# 2        NaN         NaN             NaN      NaN
# 3        NaN         NaN             NaN      NaN
# 4        NaN         NaN             NaN      NaN
#
# [5 rows x 30 columns]

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49656 entries, 0 to 49655
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Longitude (x)        49656 non-null  float64
#  1   Latitude (y)         49656 non-null  float64
#  2   Station Name         49656 non-null  object
#  3   Climate ID           49656 non-null  int64
#  4   Date/Time            49656 non-null  object
#  5   Year                 49656 non-null  int64
#  6   Month                49656 non-null  int64
#  7   Day                  49656 non-null  int64
#  8   Time                 49656 non-null  object
#  9   Temp (°C)            49273 non-null  float64
#  10  Temp Flag            331 non-null    object
#  11  Dew Point Temp (°C)  49012 non-null  float64
#  12  Dew Point Temp Flag  593 non-null    object
#  13  Rel Hum (%)          49026 non-null  float64
#  14  Rel Hum Flag         579 non-null    object
#  15  Precip. Amount (mm)  15318 non-null  float64
#  16  Precip. Amount Flag  0 non-null      float64
#  17  Wind Dir (10s deg)   46833 non-null  float64
#  18  Wind Dir Flag        1529 non-null   object
#  19  Wind Spd (km/h)      49581 non-null  float64
#  20  Wind Spd Flag        24 non-null     object
#  21  Visibility (km)      49570 non-null  float64
#  22  Visibility Flag      35 non-null     object
#  23  Stn Press (kPa)      49270 non-null  float64
#  24  Stn Press Flag       335 non-null    object
#  25  Hmdx                 8134 non-null   float64
#  26  Hmdx Flag            0 non-null      float64
#  27  Wind Chill           8862 non-null   float64
#  28  Wind Chill Flag      0 non-null      float64
#  29  Weather              7442 non-null   object
# dtypes: float64(15), int64(4), object(11)
# memory usage: 11.4+ MB

# %% [markdown]
# ### Drop Redundant Columns

# %% [markdown]
# Apart from the unnecessary columns specified in proposal, 'Stn Press (kPa)' is not important because small atmospheric pressure changes have infinitesimal effects on everyday activities.

# %%
weather_clean = weather.drop(['Year', 'Month', 'Day', 'Time', 'Station Name', 'Climate ID', 'Longitude (x)', 'Latitude (y)', 'Stn Press (kPa)'], axis=1)

# %% [markdown]
# * The 'Date/Time' column need to be converted to datetime variable and localized to 'EST' timezone.
# * The 'Weather' column is the visual observation of the weather environment and appears to be important. The missing values in this column means a clear weather. So missing values should be assigned with 'Clear'.
# * There are a number of columns containing the word 'Flag', and only contains NaN or 'M' values. According to Environment and Climate Change Canada, the 'M' represents 'missing' which means the data is unretrievable or unavailable. The flag columns can be removed since they only contain overlapping information.

# %%
# Look for and drop the columns containing the word 'Flag'
flag_columns = [col for col in weather.columns if 'Flag' in col]
weather_clean = weather_clean.drop(flag_columns, axis = 1)

# %% [markdown]
# ### Check on duplicates

# %%
weather_clean[weather_clean.duplicated(subset=['Date/Time'])]
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp (°C), Dew Point Temp (°C), Rel Hum (%), Precip. Amount (mm), Wind Dir (10s deg), Wind Spd (km/h), Visibility (km), Hmdx, Wind Chill, Weather]
# Index: []

# %% [markdown]
# There is no duplicated weather record.

# %%
weather_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49656 entries, 0 to 49655
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date/Time            49656 non-null  object
#  1   Temp (°C)            49273 non-null  float64
#  2   Dew Point Temp (°C)  49012 non-null  float64
#  3   Rel Hum (%)          49026 non-null  float64
#  4   Precip. Amount (mm)  15318 non-null  float64
#  5   Wind Dir (10s deg)   46833 non-null  float64
#  6   Wind Spd (km/h)      49581 non-null  float64
#  7   Visibility (km)      49570 non-null  float64
#  8   Hmdx                 8134 non-null   float64
#  9   Wind Chill           8862 non-null   float64
#  10  Weather              7442 non-null   object
# dtypes: float64(9), object(2)
# memory usage: 4.2+ MB

# %% [markdown]
# ### Datetime data

# %%
# Convert 'Date/Time' column to datetime variables
weather_clean['Date/Time'] = pd.to_datetime(weather_clean['Date/Time']).dt.tz_localize('US/Eastern', ambiguous=True, nonexistent='shift_backward')

# %%
weather_clean = weather_clean.set_index('Date/Time')
weather_clean.head()
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2021-11-01 00:00:00-04:00        9.3                  3.1         65.0
# 2021-11-01 01:00:00-04:00        8.5                  3.1         69.0
# 2021-11-01 02:00:00-04:00        8.0                  1.4         63.0
# 2021-11-01 03:00:00-04:00        7.7                  1.1         63.0
# 2021-11-01 04:00:00-04:00        7.0                  0.7         64.0
#
#                            Precip. Amount (mm)  Wind Dir (10s deg)  \
# Date/Time
# 2021-11-01 00:00:00-04:00                  0.0                29.0
# 2021-11-01 01:00:00-04:00                  0.0                28.0
# 2021-11-01 02:00:00-04:00                  0.0                29.0
# 2021-11-01 03:00:00-04:00                  0.0                28.0
# 2021-11-01 04:00:00-04:00                  0.0                27.0
#
#                            Wind Spd (km/h)  Visibility (km)  Hmdx  Wind Chill  \
# Date/Time
# 2021-11-01 00:00:00-04:00             30.0             16.1   NaN         NaN
# 2021-11-01 01:00:00-04:00             24.0             16.1   NaN         NaN
# 2021-11-01 02:00:00-04:00             28.0             16.1   NaN         NaN
# 2021-11-01 03:00:00-04:00             24.0             16.1   NaN         NaN
# 2021-11-01 04:00:00-04:00             21.0             16.1   NaN         NaN
#
#                           Weather
# Date/Time
# 2021-11-01 00:00:00-04:00     NaN
# 2021-11-01 01:00:00-04:00     NaN
# 2021-11-01 02:00:00-04:00     NaN
# 2021-11-01 03:00:00-04:00     NaN
# 2021-11-01 04:00:00-04:00     NaN

# %% [markdown]
# ### Missing Values

# %%
# Check missing values
weather_clean.isnull().sum()
# Out:
# Temp (°C)                383
# Dew Point Temp (°C)      644
# Rel Hum (%)              630
# Precip. Amount (mm)    34338
# Wind Dir (10s deg)      2823
# Wind Spd (km/h)           75
# Visibility (km)           86
# Hmdx                   41522
# Wind Chill             40794
# Weather                42214
# dtype: int64

# %% [markdown]
# 'Hmdx', 'Wind Chill', and 'Weather' columns have significantly more missing values than the other columns.

# %%
# Check missing values for each year
display(weather_clean.resample('Y').agg(lambda row: row.isnull().sum()))
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2017-12-31 00:00:00-05:00         11                   11           10
# 2018-12-31 00:00:00-05:00          4                    4            2
# 2019-12-31 00:00:00-05:00         95                  145          145
# 2020-12-31 00:00:00-05:00         13                   12            7
# 2021-12-31 00:00:00-05:00         26                   52           47
# 2022-12-31 00:00:00-05:00        234                  420          419
#
#                            Precip. Amount (mm)  Wind Dir (10s deg)  \
# Date/Time
# 2017-12-31 00:00:00-05:00                 8760                 530
# 2018-12-31 00:00:00-05:00                 8760                 504
# 2019-12-31 00:00:00-05:00                 8760                 595
# 2020-12-31 00:00:00-05:00                 8040                 426
# 2021-12-31 00:00:00-05:00                   14                 476
# 2022-12-31 00:00:00-05:00                    4                 292
#
#                            Wind Spd (km/h)  Visibility (km)  Hmdx  Wind Chill  \
# Date/Time
# 2017-12-31 00:00:00-05:00                9               11  7599        7251
# 2018-12-31 00:00:00-05:00                2                4  6979        7084
# 2019-12-31 00:00:00-05:00               23               24  7608        6936
# 2020-12-31 00:00:00-05:00               14               16  7211        7599
# 2021-12-31 00:00:00-05:00               21               16  7307        7383
# 2022-12-31 00:00:00-05:00                6               15  4818        4541
#
#                            Weather
# Date/Time
# 2017-12-31 00:00:00-05:00     7390
# 2018-12-31 00:00:00-05:00     7336
# 2019-12-31 00:00:00-05:00     7213
# 2020-12-31 00:00:00-05:00     7494
# 2021-12-31 00:00:00-05:00     7624
# 2022-12-31 00:00:00-05:00     5157

# %% [markdown]
# #### **Imputing/filling Hmdx and Wind Chill missing values**
#
# According to Environment and Climate Change Canada (https://climate.weather.gc.ca/glossary_e.html), the humidex values are only reported if:
#
#   (1) air temperature is greater than or equal to 20 degrees celsius and,
#
#   (2) the humidex value is at least 1 degree greater than the air temperature.
#
# Similarily, wind chill is only calculated if the air temperature is greater than or equal to 0 degrees celsius.

# %%
# Visualizing number of missing values in 'Hmdx' and 'Wind Chill' columns
weather_clean.resample('M').agg(lambda row: row.isnull().sum())[['Hmdx', 'Wind Chill']].plot(figsize = (10, 6))

plt.title('Number of missing values for Hmdx and Wind Chill columns', fontsize = 18)
plt.xlabel('Time', fontsize = 15)
plt.ylabel('Missing Value Count', fontsize = 15)
plt.legend(['Hmdx', 'Wind Chill'], fontsize = 14)

# %% [markdown]
# We can find that there are more missing wind chill values and fewer missing humidex values in the summer, and vice versa in the winter. This agrees with the explanation provided by Environment and Climate Change Canada.
#
# Therefore, the missing values in 'Hmdx' and 'Wind Chill' should not be modified.

# %% [markdown]
# #### **Imputing/filling Weather missing values**

# %%
weather_clean['Weather'].unique()
# Out:
# array([nan, 'Rain', 'Fog', 'Moderate Rain', 'Rain,Fog', 'Snow', 'Haze',
#        'Thunderstorms', 'Thunderstorms,Rain', 'Thunderstorms,Rain,Fog',
#        'Moderate Rain,Fog', 'Rain,Snow', 'Freezing Rain,Snow',
#        'Moderate Snow', 'Heavy Rain,Fog', 'Thunderstorms,Moderate Rain',
#        'Thunderstorms,Fog', 'Thunderstorms,Heavy Rain,Fog',
#        'Freezing Rain,Fog', 'Freezing Rain',
#        'Thunderstorms,Moderate Rain,Fog', 'Thunderstorms,Heavy Rain',
#        'Snow,Blowing Snow', 'Heavy Snow', 'Haze,Blowing Snow'],
#       dtype=object)

# %% [markdown]
# The weather feature contains weather phenomenon, and therefore the NaN values should represent a clear day. We can fill the missing values using "Clear" str.

# %%
# Modifying missing values in 'Weather' column
weather_clean['Weather'].fillna('Clear', inplace = True)
weather_clean.head()
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2021-11-01 00:00:00-04:00        9.3                  3.1         65.0
# 2021-11-01 01:00:00-04:00        8.5                  3.1         69.0
# 2021-11-01 02:00:00-04:00        8.0                  1.4         63.0
# 2021-11-01 03:00:00-04:00        7.7                  1.1         63.0
# 2021-11-01 04:00:00-04:00        7.0                  0.7         64.0
#
#                            Precip. Amount (mm)  Wind Dir (10s deg)  \
# Date/Time
# 2021-11-01 00:00:00-04:00                  0.0                29.0
# 2021-11-01 01:00:00-04:00                  0.0                28.0
# 2021-11-01 02:00:00-04:00                  0.0                29.0
# 2021-11-01 03:00:00-04:00                  0.0                28.0
# 2021-11-01 04:00:00-04:00                  0.0                27.0
#
#                            Wind Spd (km/h)  Visibility (km)  Hmdx  Wind Chill  \
# Date/Time
# 2021-11-01 00:00:00-04:00             30.0             16.1   NaN         NaN
# 2021-11-01 01:00:00-04:00             24.0             16.1   NaN         NaN
# 2021-11-01 02:00:00-04:00             28.0             16.1   NaN         NaN
# 2021-11-01 03:00:00-04:00             24.0             16.1   NaN         NaN
# 2021-11-01 04:00:00-04:00             21.0             16.1   NaN         NaN
#
#                           Weather
# Date/Time
# 2021-11-01 00:00:00-04:00   Clear
# 2021-11-01 01:00:00-04:00   Clear
# 2021-11-01 02:00:00-04:00   Clear
# 2021-11-01 03:00:00-04:00   Clear
# 2021-11-01 04:00:00-04:00   Clear

# %% [markdown]
# #### **Imputing/filling missing values for other columns**
#
# The weather data is sampled every hour, so it should be reasonable to impute missing values based on the time-adjacent valid observations. Except for 'Hmdx', 'Wind Chill', and 'Weather' columns, all other columns will have missing values filled using linear interpolation between valid observations.

# %%
# Linear interpolating values 
interpolating_col = weather_clean.columns.drop(['Hmdx', 'Wind Chill', 'Weather'])
weather_clean[interpolating_col] = weather_clean[interpolating_col].interpolate(
    method = 'linear', axis = 0, limit_direction = 'both').round(1)

# %%
# Check if there are still missing values
weather_clean.isnull().sum()
# Out:
# Temp (°C)                  0
# Dew Point Temp (°C)        0
# Rel Hum (%)                0
# Precip. Amount (mm)        0
# Wind Dir (10s deg)         0
# Wind Spd (km/h)            0
# Visibility (km)            0
# Hmdx                   41522
# Wind Chill             40794
# Weather                    0
# dtype: int64

# %% [markdown]
# ### Outliers

# %% [markdown]
# Check if there are outliers for temperature.

# %%
weather_clean.describe()
# Out:
#           Temp (°C)  Dew Point Temp (°C)   Rel Hum (%)  Precip. Amount (mm)  \
# count  49656.000000         49656.000000  49656.000000         49656.000000
# mean       9.374633             4.459922     72.786562             0.021677
# std        9.962969            10.320747     15.143704             0.289845
# min      -21.900000           -28.400000     16.000000             0.000000
# 25%        1.800000            -2.900000     63.000000             0.000000
# 50%        8.700000             4.100000     74.000000             0.000000
# 75%       18.300000            13.300000     85.000000             0.000000
# max       34.100000            24.700000    100.000000            18.200000
#
#        Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)         Hmdx  \
# count        49656.000000     49656.000000     49656.000000  8134.000000
# mean            19.933452        17.200077        15.121133    29.486354
# std              9.860376        10.206580         3.051877     3.186370
# min              1.000000         0.000000         0.000000    25.000000
# 25%              8.800000         9.000000        16.100000    27.000000
# 50%             22.000000        15.000000        16.100000    29.000000
# 75%             28.000000        22.000000        16.100000    31.000000
# max             36.000000        76.000000        16.100000    43.000000
#
#         Wind Chill
# count  8862.000000
# mean    -11.141954
# std       5.343303
# min     -36.000000
# 25%     -14.000000
# 50%     -10.000000
# 75%      -7.000000
# max      -1.000000

# %%
# draw boxplots to visualize outliers
plt.figure(figsize=(12,8))
outlier_columns = [
    'Temp (°C)', 'Dew Point Temp (°C)', 'Rel Hum (%)', 
    'Wind Spd (km/h)', 'Hmdx', 'Wind Chill'
    ]

for i, feature in enumerate(outlier_columns): 
    plt.subplot(2,3,i+1)
    fig = weather_clean.boxplot(column=outlier_columns[i])
    fig.set_ylabel(feature)

plt.show()

# %%
# draw distplot to visualize outliers
plt.figure(figsize=(6,8))
other_columns = ['Visibility (km)', 'Precip. Amount (mm)']
plt.subplot(2,1,1)
sns.distplot(weather_clean[other_columns[0]])
plt.subplot(2,1,2)
sns.distplot(weather_clean[other_columns[1]])
plt.show()

# %% [markdown]
# * Wind Dir (10s deg) should not be checked for outliers since this represent the direction of wind.
# * There is no outlier for 'Temp (°C)', which means the weather records are rather reliable.
# * The outliers for 'Dew Point Temp (°C)', 'Rel Hum (%)', 'Wind Spd (km/h)', 'Hmdx', 'Wind Chill' actually represents extreme weather condition and should not be removed or capped.
# * Visibility and Precip. Amount features distribution tells that most of the days are clear and without precipitation. And the outliers also represents extreme weather condition. So they should not be removed or capped.

# %% [markdown]
# **Conclusion:** There is no need to remove outliers. The weather data is cleaned! Note that the NaN value for Wind Chill and Hmdx should not be treated as a simple zero.

# %%
weather_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 49656 entries, 2021-11-01 00:00:00-04:00 to 2020-12-31 23:00:00-05:00
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Temp (°C)            49656 non-null  float64
#  1   Dew Point Temp (°C)  49656 non-null  float64
#  2   Rel Hum (%)          49656 non-null  float64
#  3   Precip. Amount (mm)  49656 non-null  float64
#  4   Wind Dir (10s deg)   49656 non-null  float64
#  5   Wind Spd (km/h)      49656 non-null  float64
#  6   Visibility (km)      49656 non-null  float64
#  7   Hmdx                 8134 non-null   float64
#  8   Wind Chill           8862 non-null   float64
#  9   Weather              49656 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 4.2+ MB

# %% [markdown]
# ## Bike Share Trip Data

# %% [markdown]
# ### Load Bike Share Trip Data

# %%
# Define the rubbish character in front of the 'trip id' columns in some files
rubbish = ''.join([chr(c) for c in codecs.BOM_UTF8])

def read_bikeshare_csv(path):
    """
    Create a function to read bike share trips csv files without the rubbish character.
    """
    with open(path, encoding='utf-8') as f:
        txt = f.read()
        if txt.startswith(rubbish):
            txt = txt[len(rubbish):]
            
        return pd.read_csv(StringIO(txt), encoding='utf-8', encoding_errors='ignore')

# %%
# Set bikeshare data path
path_ridership = os.path.join(os.path.abspath(os.getcwd()), 'data', 'ridership')

# Create a list of file names for bike share trips data
trips_filenames = [filename for filename in os.listdir(path_ridership) if 'bike_share' in filename]

# Create a dictionary where key:value pairs correspond to the file name and DataFrame respectively
trips_data = {filename: read_bikeshare_csv(os.path.join(path_ridership, filename)) for filename in trips_filenames}

# %%
# Check the column names of all files
for filename in trips_filenames:
    print(format(trips_data[filename].columns.tolist()))
# Out:
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_duration_seconds', 'from_station_id', 'trip_start_time', 'from_station_name', 'trip_stop_time', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['Trip Id', 'Subscription Id', 'Trip  Duration', 'Start Station Id', 'Start Time', 'Start Station Name', 'End Station Id', 'End Time', 'End Station Name', 'Bike Id', 'User Type']
# ['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds', 'from_station_id', 'from_station_name', 'to_station_id', 'to_station_name', 'user_type']

# %%
# Rename the columns in 2017 and 2018 data
trips_rename = {
    'trip_id' : 'Trip Id',
    'trip_start_time' : 'Start Time',
    'trip_stop_time' : 'End Time',
    'trip_duration_seconds' : 'Trip Duration',
    'from_station_id' : 'Start Station Id',
    'from_station_name' : 'Start Station Name',
    'to_station_id' : 'End Station Id',
    'to_station_name' : 'End Station Name',
    'user_type' : 'User Type'
}

for filename in trips_filenames:
    if ('2017' in filename) or ('2018' in filename):
        trips_data[filename].rename(columns=trips_rename, inplace=True)
    else:
        trips_data[filename].rename(columns={'Trip  Duration' : 'Trip Duration'}, inplace=True)

# %%
# Concatenate the ridership data into one dataframe 
ridership = pd.concat([trips_data[filename] for filename in trips_filenames], ignore_index=True)

# View DataFrame
ridership.head()
# Out:
#     Trip Id  Trip Duration  Start Station Id                 Start Time  \
# 0  16734202           1602            7216.0  01/07/2022 00:00:00 (EST)
# 1  16734203            990            7033.0  01/07/2022 00:00:00 (EST)
# 2  16734204            653            7184.0  01/07/2022 00:00:00 (EST)
# 3  16734205            811            7199.0  01/07/2022 00:00:00 (EST)
# 4  16734206           1003            7033.0  01/07/2022 00:00:00 (EST)
#
#               Start Station Name  End Station Id                   End Time  \
# 0  Wellington St W / Stafford St          7203.0  01/07/2022 00:26:00 (EST)
# 1                  Union Station          7474.0  01/07/2022 00:16:00 (EST)
# 2     Ossington Ave / College St          7368.0  01/07/2022 00:11:00 (EST)
# 3        College St / Markham St          7533.0  01/07/2022 00:13:00 (EST)
# 4                  Union Station          7474.0  01/07/2022 00:17:00 (EST)
#
#                                 End Station Name  Bike Id      User Type  \
# 0  Bathurst St/Queens Quay(Billy Bishop Airport)   6420.0  Casual Member
# 1                                Clarence Square   2092.0  Casual Member
# 2                    Lisgar St / Dundas St SMART   4220.0  Annual Member
# 3                     Housey St / Dan Leckie Way    663.0  Annual Member
# 4                                Clarence Square    553.0  Casual Member
#
#    Subscription Id
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
ridership.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15358993 entries, 0 to 15358992
# Data columns (total 11 columns):
#  #   Column              Non-Null Count     Dtype
# ---  ------              --------------     -----
#  0   Trip Id             15358993 non-null  int64
#  1   Trip Duration       15358993 non-null  int64
#  2   Start Station Id    14332100 non-null  float64
#  3   Start Time          15358993 non-null  object
#  4   Start Station Name  15262057 non-null  object
#  5   End Station Id      14327681 non-null  float64
#  6   End Time            15358992 non-null  object
#  7   End Station Name    15256259 non-null  object
#  8   Bike Id             11943393 non-null  float64
#  9   User Type           15358993 non-null  object
#  10  Subscription Id     5052221 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.3+ GB

# %%
ridership['User Type'].unique()
# Out:
# array(['Casual Member', 'Annual Member', 'Member', 'Casual'], dtype=object)

# %% [markdown]
# **Problems in the dataset:**
# * There are a lot of null values, especially in station id and station name columns.
# * Start Time and End Time values need to be first converted into datatime variables with timezone info and then converted to 'US/Eastern' timezone.
# * User Types need to be unified in one format.
# * Subscription Id and Bike Id are only included in some years and are less useful information. So they need to be dropped.
# * There is one missing value in End Time column.

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# **Drop redundant columns**

# %%
#Drop Bike ID and Subscription ID columns
ridership.drop(['Subscription Id', 'Bike Id'], axis=1, inplace=True)

# %% [markdown]
# **Unify user type formats**

# %%
user_rename = {
    'Annual Member' : 'Member',
    'Casual Member' : 'Casual'
}

ridership['User Type'].replace(user_rename, inplace=True)

# %% [markdown]
# **Drop the row with null End Time**

# %%
ridership[ridership['End Time'].isnull()==True]
# Out:
#          Trip Id  Trip Duration  Start Station Id              Start Time  \
# 9754385  2302635              0               NaN  2017-11-29 10:53 (UTC)
#
#               Start Station Name  End Station Id End Time End Station Name  \
# 9754385  Seaton St / Dundas St E             NaN      NaN              NaN
#
#         User Type
# 9754385    Casual

# %%
#Drop the row with null End Time
ridership = ridership[ridership['End Time'].isnull()==False]

# %% [markdown]
# **Check on duplicate trip records**

# %%
# Check if there are duplicate trips
ridership['Trip Id'].nunique() / len(ridership)
# Out:
# 0.9999991535902877

# %%
trip_duplicates = ridership[ridership.duplicated('Trip Id')]
trip_duplicates
# Out:
#           Trip Id  Trip Duration  Start Station Id                 Start Time  \
# 6763683  12272296              0            7090.0  29/06/2021 23:59:00 (EST)
# 6764962  12273983              0            7078.0  30/06/2021 08:47:00 (EST)
# 6770921  12281090              0            7101.0  30/06/2021 17:24:00 (EST)
# 7984479  11180718              0            7271.0  18/04/2021 15:50:00 (EST)
# 8020463  11224466              0            7649.0  24/04/2021 14:14:00 (EST)
# 8028339  11233036              0            7017.0  24/04/2021 18:09:00 (EST)
# 8530765  10909571              0            7351.0  18/03/2021 17:32:00 (EST)
# 8563120  10947892              0            7119.0  22/03/2021 19:02:00 (EST)
# 8568848  10954749              0            7254.0  23/03/2021 17:49:00 (EST)
# 8599519  10991914              0            7248.0  28/03/2021 17:45:00 (EST)
# 8600473  10993058              0            7043.0  28/03/2021 21:42:00 (EST)
# 8609894  11004236              0            7656.0  30/03/2021 16:45:00 (EST)
# 9163127  10756846              0            7207.0  03/02/2021 17:11:00 (EST)
#
#                                Start Station Name  End Station Id  \
# 6763683                   Danforth Ave / Lamb Ave          7156.0
# 6764962                     College St / Major St          7339.0
# 6770921       Lower Sherbourne St / The Esplanade          7014.0
# 7984479           Yonge St / Alexander St - SMART          7267.0
# 8020463          Greenwood Subway Station - SMART          7611.0
# 8028339                 Widmer St / Adelaide St W          7634.0
# 8530765                Pretoria Av / Broadview Av          7286.0
# 8563120  Sumach St / Carlton St. (Riverdale Farm)          7458.0
# 8568848            Borden St / Bloor St W - SMART          7023.0
# 8599519         Baldwin Ave / Spadina Ave - SMART          7020.0
# 8600473           Queens Quay W / Lower Simcoe St          7020.0
# 8609894                    Bloor St W / Brock Ave          7240.0
# 9163127                 Dundas St W / Crawford St          7112.0
#
#                           End Time  \
# 6763683  29/06/2021 23:59:00 (EST)
# 6764962  30/06/2021 08:47:00 (EST)
# 6770921  30/06/2021 17:24:00 (EST)
# 7984479  18/04/2021 15:50:00 (EST)
# 8020463  24/04/2021 14:14:00 (EST)
# 8028339  24/04/2021 18:09:00 (EST)
# 8530765  18/03/2021 17:32:00 (EST)
# 8563120  22/03/2021 19:02:00 (EST)
# 8568848  23/03/2021 17:49:00 (EST)
# 8599519  28/03/2021 17:45:00 (EST)
# 8600473  28/03/2021 21:42:00 (EST)
# 8609894  30/03/2021 16:45:00 (EST)
# 9163127  03/02/2021 17:11:00 (EST)
#
#                                      End Station Name User Type
# 6763683                        Salem Ave / Bloor St W    Member
# 6764962                   Carlaw Ave / Strathcona Ave    Member
# 6770921    Sherbourne St / Carlton St (Allan Gardens)    Casual
# 7984479             Dundas St E / Pembroke St - SMART    Member
# 8020463              Victoria Park Ave / Danforth Ave    Member
# 8028339  University Ave / Gerrard St W (WEST) - SMART    Casual
# 8530765              Gerrard St E / Broadview - SMART    Member
# 8563120                        Church St / Lombard St    Casual
# 8568848                        College St / Borden St    Member
# 8599519                       Phoebe St / Spadina Ave    Casual
# 8600473                       Phoebe St / Spadina Ave    Casual
# 8609894                 Bloor St W / Shaw Ave - SMART    Member
# 9163127               Liberty St / Fraser Ave Green P    Member

# %% [markdown]
# The duplicated trips have trip duration of 0 second, which means they are probably produced due to errors. And they will be removed later when removing trip duration outliers. So there is no need to deal with them at this moment.

# %% [markdown]
# ### Split ridership data for different years
# The ridership data is splited into small dataframes for different years for better preliminary analyze and data cleaning.

# %%
# Separate ridership data according to year
ridership_2017 = ridership.loc[ridership['Start Time'].str.contains('2017')]
ridership_2018 = ridership.loc[ridership['Start Time'].str.contains('2018')]
ridership_2019 = ridership.loc[ridership['Start Time'].str.contains('2019')]
ridership_2020 = ridership.loc[ridership['Start Time'].str.contains('2020')]
ridership_2021 = ridership.loc[ridership['Start Time'].str.contains('2021')]
ridership_2022 = ridership.loc[ridership['Start Time'].str.contains('2022')]

# %% [markdown]
# ### Datetime data
# Since we are going to conduct datetime convert for each year, we can define a function.
# There are two formats in the datetime columns in all ridership data, we need to treat them separately for different timezones, also because pd.to_datetime can't deal with mixed time formats:
# * When there is a str "UTC" in the Time columns, it means that the data was downloaded as UTC time, therefore it is first localized to UTC timezone and then converted to US/Eastern timezone.
# * When there is a str "EST" in the Time columns, it means that the data was downloaded as EST time, therefore it should be localized to US/Eastern timezone.
#
# The Daylight Saving Time (DST) is set to be true since the bikeshare data is collected in Toronto.

# %%
# Create a time_convert function to convert Start Time and End Time into datetime variables
def time_convert(df):
    """Convert Start Time and End Time into datetime variables
    Using pd.to_datetime for each specific time format. DST is set to be True.
    """
    df_copy = df.copy()

    if 'UTC' in df_copy['Start Time'].iloc[0]:
        df_copy['Start Time'] = pd.to_datetime(df['Start Time'].str[:16], format='%Y-%m-%d %H:%M')\
            .dt.tz_localize('UTC', ambiguous=True, nonexistent='shift_backward')\
                .dt.tz_convert('US/Eastern')
        df_copy['End Time'] = pd.to_datetime(df['End Time'].str[:16], format='%Y-%m-%d %H:%M')\
            .dt.tz_localize('UTC', ambiguous=True, nonexistent='shift_backward')\
                .dt.tz_convert('US/Eastern')
    else:
        df_copy['Start Time'] = pd.to_datetime(df['Start Time'].str[:16], format='%d/%m/%Y %H:%M')\
            .dt.tz_localize('US/Eastern', ambiguous=True, nonexistent='shift_backward')
        df_copy['End Time'] = pd.to_datetime(df['End Time'].str[:16], format='%d/%m/%Y %H:%M')\
            .dt.tz_localize('US/Eastern', ambiguous=True, nonexistent='shift_backward')
   
    return df_copy

# %% [markdown]
# ### Missing Values

# %% [markdown]
# After converting the datetime values, the dataframe is stored in dataframes named `ridership_est` with year suffixes. Then the data of each year is cleaned accordingly.
#
# First we create a function to remove the rows with 'Trip Duration' outliers. Normally trips shorter than 60 sec are considered non-existent, so we can safely remove these trips. Also trips too short or too long are usually created due to mistake or errors, so we will remove these trips from the dataframe. Then we also print out the percent of outliers removed to know the data structure better.

# %%
# Create a remove_outliers function to remove the rows with trip duration outliers.
def remove_outliers(data):
    """
    Create a function tto remove the rows with trip duration outliers in the dataset
    The input data is a dataframe with column named 'Trip Duration'.
    """

    data_len = len(data)

    # Narrow down our dataset with 60 seconds duration filter
    data = data[data['Trip Duration']>=60]
    
    # Compute quartiles
    Q1 = data ['Trip Duration'].quantile(0.25)
    Q3 = data ['Trip Duration'].quantile(0.75)
    IQR = Q3 - Q1
    data = data[(data['Trip Duration']<=(Q3+1.5*IQR)) & (data['Trip Duration']>=(Q1-1.5*IQR))]

    print("Percent of outliers removed: {}%".format((1-len(data) / data_len) * 100))
    
    return data

# %% [markdown]
# #### **2017 Data**

# %%
ridership_est_2017 = time_convert(ridership_2017)

# %%
# Create a functio to plot distribution of a variable in a dataframe
def plot_distribution(var, df):
    """
    The function takes two input. 
    df (dataframe).
    var (str) : it is a column name in df.
    """

    sns.boxplot(x=var, data=df)
    plt.xlabel(var)
    plt.title('Distribution of {} '.format(var))
    plt.show()

    return

# %%
plot_distribution('Trip Duration', ridership_est_2017)

# %%
# Remove trip duration outliers
ridership_est_2017 = remove_outliers(ridership_est_2017)
# Out:
# Percent of outliers removed: 7.65510161413967%

# %%
plot_distribution('Trip Duration', ridership_est_2017)

# %%
ridership_est_2017.isnull().sum()
# Out:
# Trip Id                    0
# Trip Duration              0
# Start Station Id      934205
# Start Time                 0
# Start Station Name         0
# End Station Id        934205
# End Time                   0
# End Station Name           0
# User Type                  0
# dtype: int64

# %% [markdown]
# The missing Station Id can probably be filled using the Station Data. Let's first check out what does these trip look like.
#
# To have an understanding of how the missing values generated, we also need to check when were they generated.

# %%
# Check the trips with missing Start Station Id and End Station Id
empty_2017 = ridership_est_2017[
    (ridership_est_2017['Start Station Id'].isnull()==True) | 
    (ridership_est_2017['End Station Id'].isnull()==True)]

empty_2017.head()
# Out:
#          Trip Id  Trip Duration  Start Station Id                Start Time  \
# 4003950  1485285            290               NaN 2017-08-01 01:00:00-04:00
# 4003951  1485286            311               NaN 2017-08-01 01:02:00-04:00
# 4003952  1485287           1053               NaN 2017-08-01 01:02:00-04:00
# 4003953  1485288            502               NaN 2017-08-01 01:02:00-04:00
# 4003954  1485289            803               NaN 2017-08-01 01:04:00-04:00
#
#                  Start Station Name  End Station Id                  End Time  \
# 4003950     University Ave / Elm St             NaN 2017-08-01 01:04:00-04:00
# 4003951  Queen St W / Dovercourt Rd             NaN 2017-08-01 01:07:00-04:00
# 4003952      Roxton Rd / Harbord St             NaN 2017-08-01 01:19:00-04:00
# 4003953   Cherry St / Distillery Ln             NaN 2017-08-01 01:10:00-04:00
# 4003954     Ulster St / Bathurst St             NaN 2017-08-01 01:17:00-04:00
#
#                    End Station Name User Type
# 4003950       College St / Huron St    Member
# 4003951  Niagara St / Richmond St W    Member
# 4003952       Yonge St / Aylmer Ave    Member
# 4003953       Yonge St / Harbour St    Member
# 4003954          Yonge St / Wood St    Member

# %%
# Visualize the error trips counts among different months.
empty_2017['Month'] = empty_2017['Start Time'].dt.month
sns.countplot(data=empty_2017, x='Month', hue='User Type')
plt.show()

# %% [markdown]
# This happened after 2017 July, so a guess is that there were some name changing of the stations or main updating of the station Id or names that caused this error since July. We can probably find the missing Id using the station names.

# %% [markdown]
# We will use station data as a reference to find missing Station Id. Since this process will probably be conducted multiple times for different year data, we create a function `fill_id` to do so.

# %%
# Create a fill_id function for filling missing station ID according to station name
def fill_id(df):
    """This function is for filling missing station names according to station ID
    using the bikeshare_stations data as reference.
    """
    
    df['Start Station Id'].fillna(
        df['Start Station Name'].map(bikeshare_stations.set_index('Station Name')['Station Id']),
        inplace=True)
    
    df['End Station Id'].fillna(
        df['End Station Name'].map(bikeshare_stations.set_index('Station Name')['Station Id']),
        inplace=True)
    
    return df

# %% [markdown]
# Also, we create a `fill_name` function to find the missing station names according to station ID using the station data as a reference.

# %%
# Create a fill_name function for filling missing station name according to station ID
def fill_name(df):
    """This function is for filling missing station names according to station ID.
    using the bikeshare_stations as reference.
    """

    df['Start Station Name'].fillna(
        df['Start Station Id'].map(bikeshare_stations.set_index('Station Id')['Station Name']),
        inplace=True)
    
    df['End Station Name'].fillna(
        df['End Station Id'].map(bikeshare_stations.set_index('Station Id')['Station Name']),
        inplace=True)
    
    return df

# %%
fill_id(ridership_est_2017)
# Out:
#           Trip Id  Trip Duration  Start Station Id                Start Time  \
# 4003950   1485285            290            7004.0 2017-08-01 01:00:00-04:00
# 4003951   1485286            311            7197.0 2017-08-01 01:02:00-04:00
# 4003952   1485287           1053            7196.0 2017-08-01 01:02:00-04:00
# 4003953   1485288            502            7107.0 2017-08-01 01:02:00-04:00
# 4003954   1485289            803            7195.0 2017-08-01 01:04:00-04:00
# ...           ...            ...               ...                       ...
# 15358988   868761            577            7021.0 2017-04-01 00:42:00-04:00
# 15358989   868762            292            7069.0 2017-04-01 00:50:00-04:00
# 15358990   868763            709            7010.0 2017-04-01 00:51:00-04:00
# 15358991   868764            699            7058.0 2017-04-01 00:53:00-04:00
# 15358992   868765            572            7047.0 2017-04-01 00:54:00-04:00
#
#                      Start Station Name  End Station Id  \
# 4003950         University Ave / Elm St          7007.0
# 4003951      Queen St W / Dovercourt Rd          7046.0
# 4003952          Roxton Rd / Harbord St          7128.0
# 4003953       Cherry St / Distillery Ln          7067.0
# 4003954         Ulster St / Bathurst St          7163.0
# ...                                 ...             ...
# 15358988             Bay St / Albert St          7024.0
# 15358989       Queen St W / Spadina Ave          7037.0
# 15358990        King St W / Spadina Ave          7060.0
# 15358991              Huron/ Harbord St          7057.0
# 15358992  University Ave / Gerrard St W          7044.0
#
#                           End Time             End Station Name User Type
# 4003950  2017-08-01 01:04:00-04:00        College St / Huron St    Member
# 4003951  2017-08-01 01:07:00-04:00   Niagara St / Richmond St W    Member
# 4003952  2017-08-01 01:19:00-04:00        Yonge St / Aylmer Ave    Member
# 4003953  2017-08-01 01:10:00-04:00        Yonge St / Harbour St    Member
# 4003954  2017-08-01 01:17:00-04:00           Yonge St / Wood St    Member
# ...                            ...                          ...       ...
# 15358988 2017-04-01 00:52:00-04:00     Dundonald St / Church St    Member
# 15358989 2017-04-01 00:55:00-04:00    Bathurst St / Dundas St W    Member
# 15358990 2017-04-01 01:02:00-04:00    Princess St / Adelaide St    Member
# 15358991 2017-04-01 01:04:00-04:00  Simcoe St / Wellington St W    Member
# 15358992 2017-04-01 01:03:00-04:00     Church St / Alexander St    Member
#
# [1378074 rows x 9 columns]

# %%
ridership_est_2017.isnull().sum()
# Out:
# Trip Id                    0
# Trip Duration              0
# Start Station Id      236883
# Start Time                 0
# Start Station Name         0
# End Station Id        241751
# End Time                   0
# End Station Name           0
# User Type                  0
# dtype: int64

# %% [markdown]
# Missing Station Id can be largely reduced using `fill_id`, yet there are still lots of missing values. So we'd like to look at these rows again.

# %%
#Check again the trips with missing Station Id
ridership_est_2017[
    (ridership_est_2017['Start Station Id'].isnull()==True) | 
    (ridership_est_2017['End Station Id'].isnull()==True)].head()
# Out:
#          Trip Id  Trip Duration  Start Station Id                Start Time  \
# 4003956  1485291           1214            7169.0 2017-08-01 01:08:00-04:00
# 4003957  1485292            199            7046.0 2017-08-01 01:09:00-04:00
# 4003958  1485293            366               NaN 2017-08-01 01:11:00-04:00
# 4003967  1485302           1136               NaN 2017-08-01 01:16:00-04:00
# 4003968  1485303            438            7044.0 2017-08-01 01:17:00-04:00
#
#                        Start Station Name  End Station Id  \
# 4003956  Front St W / Bay St (North Side)             NaN
# 4003957        Niagara St / Richmond St W             NaN
# 4003958      Parliament St / Aberdeen Ave          7024.0
# 4003967               Bay St / Bloor St W          7176.0
# 4003968          Church St / Alexander St             NaN
#
#                          End Time              End Station Name User Type
# 4003956 2017-08-01 01:29:00-04:00      Spadina Ave / Sussex Ave    Member
# 4003957 2017-08-01 01:12:00-04:00      Queen St W / Portland St    Member
# 4003958 2017-08-01 01:17:00-04:00      Dundonald St / Church St    Member
# 4003967 2017-08-01 01:35:00-04:00  Bathurst St / Fort York Blvd    Casual
# 4003968 2017-08-01 01:24:00-04:00       Seaton St / Dundas St E    Casual

# %% [markdown]
# The remaining missing values are because there are inconsistency issues with the station names. Some of the stations names can't be found in `bikeshare_stations` data possibly due to station upgrade or typos. For example, the station shown above named "Beverly St / College St" actually have a correct name "Beverley St / College St" in the `bikeshare_stations` data. So we need to update the Station Names based on `bikeshare_stations` data, replacing all messy station names to their most updated names. Meanwhile we also want to avoid mistakenly matching stations with similar names but are actually not the same stations. A good way to do it is to match messy names with new names using their only station ID.

# %%
# Obtain an updated station name list from bikeshare_stations dataset
station_names = bikeshare_stations['Station Name'].unique()

# %% [markdown]
# The stations without Station ID may not have exact matched names in bikeshare_station data, but we can probably find entries with the same names in ridership data that has Station ID. Since one station ID may relate to multiple messy names, but one station can only have one station ID. We can then use this ID to find the updated name for each station.

# %%
# Create a dataframe stations_old to store all old (messy) names and their relating station ID from the ridership dataframe.
# Extract both starting station names and ending station names from the ridership dataframe as old station names
stations_start = ridership[['Start Station Id', 'Start Station Name']]
stations_end = ridership[['End Station Id', 'End Station Name']]
stations_start.columns = stations_end.columns = ['Station Id', 'Station Name']

# Combine the stations into a single dataframe stations_old
stations_old = pd.concat([stations_start, stations_end]).dropna(how='all').drop_duplicates().reset_index(drop=True)
stations_old = stations_old.dropna(subset='Station Name')

# Drop rows with duplicate station names, keeping the one with a Station Id
stations_old = stations_old.sort_values(['Station Id'], na_position='last').drop_duplicates('Station Name', keep='first')

# %%
stations_old.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 86 to 1057
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Station Id    807 non-null    float64
#  1   Station Name  817 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 19.1+ KB

# %%
stations_old.nunique()
# Out:
# Station Id      626
# Station Name    817
# dtype: int64

# %% [markdown]
# It seems that there are 817 unique old (messy) stations names in all ridership dataset while the station ID is less than that. Which means we do have a lot of stations that are represented by multiple station names in the ridership data.
#
# There are also 10 station names that don't have a relating station ID in the ridership dataset. We can try filling these ID for these station names in order to find their new station names later.

# %%
# try finding the stations with missing ID using bikeshare_stations data
stations_old['Station Id'].fillna(
    stations_old['Station Name'].map(bikeshare_stations.set_index('Station Name')['Station Id']),
    inplace=True)

# %%
# Separate the stations names that has no station ID
stations_old_ID = stations_old[stations_old['Station Id'].isnull()==False]
stations_old_noID = stations_old[stations_old['Station Id'].isnull()==True]
stations_old_noID
# Out:
#       Station Id                                   Station Name
# 800          NaN             Michael Sweet Ave / St. Patrick St
# 833          NaN                        Beverly St / College St
# 861          NaN                    Margueretta St / College St
# 929          NaN                       Lansdowne Subway Green P
# 991          NaN                         Roxton Rd / College St
# 993          NaN                                   Base Station
# 999          NaN  Lake Shore Blvd W / Ontario Dr(Ontario Place)
# 1049         NaN            Dovercourt Rd / Harrison St - SMART
# 1051         NaN         Summerhill Ave / MacLennan Ave - SMART
# 1057         NaN                       Fringe Next Stage - 7219

# %% [markdown]
# These stations may have new names in the updated bikeshare_stations data. So we can use `fuzzywuzzy` to find their possible new name and then try to fill their missing ID accordingly.

# %%
# Create a find_fuzz function for find the updated station names using fuzz.
# We use token sort ratio from fuzz to match two similar strings as possible pairs
# of old and new station names. If the order in which the words are placed in 
# a particular sentence doesn’t matter then the best way to match two strings 
# is by the use of Token Sort Ratio.

def find_fuzz(old_name, station_names):
    """This function find a new_name in the bikeshare_station dataset
    for an old_name using the fuzzywuzzy.
    """
    # When the matching score is below threshold, the output is 'No Match Station'
    result_dict  = {0: 'No Match Station'}
    
    if old_name in station_names:
        return old_name
    else:
        for new_name in station_names:
            if fuzz.token_sort_ratio(new_name,old_name) >= 80:
                result_dict[fuzz.token_sort_ratio(new_name,old_name)] = str(new_name)
    
    result = result_dict[max(result_dict.keys())]
    
    return result

# %%
# find possible new names for the stations with no ID
find_fuzzname = stations_old_noID.copy()
find_fuzzname['possible_new_name'] = find_fuzzname['Station Name'].apply(lambda row: find_fuzz(row, station_names))
find_fuzzname
# Out:
#       Station Id                                   Station Name  \
# 800          NaN             Michael Sweet Ave / St. Patrick St
# 833          NaN                        Beverly St / College St
# 861          NaN                    Margueretta St / College St
# 929          NaN                       Lansdowne Subway Green P
# 991          NaN                         Roxton Rd / College St
# 993          NaN                                   Base Station
# 999          NaN  Lake Shore Blvd W / Ontario Dr(Ontario Place)
# 1049         NaN            Dovercourt Rd / Harrison St - SMART
# 1051         NaN         Summerhill Ave / MacLennan Ave - SMART
# 1057         NaN                       Fringe Next Stage - 7219
#
#                                   possible_new_name
# 800                                No Match Station
# 833                        Beverley St / College St
# 861                                No Match Station
# 929                                No Match Station
# 991                                No Match Station
# 993                                No Match Station
# 999                  Lake Shore Blvd W / Ontario Dr
# 1049  Dovercourt Rd / Harrison St (Green P) - SMART
# 1051                 Summerhill Ave / Maclennan Ave
# 1057                               No Match Station

# %% [markdown]
# We can then have a look at it and manually replace some statins with their actual name.
#
# The stations with no match name can be drop since they are probably canceled stations with no known station ID and they are a small part of the whole stations.

# %%
# Manually select some stations with their actual name
fuzznames = ['Beverly St / College St', 
             'Dovercourt Rd / Harrison St - SMART',
             'Lake Shore Blvd W / Ontario Dr(Ontario Place)',
             'Summerhill Ave / MacLennan Ave - SMART']

find_fuzzname = find_fuzzname[find_fuzzname['Station Name'].isin(fuzznames)]

# %%
# fill the missing stations Id with possible new names in find_fuzzname
find_fuzzname['Station Id'].fillna(
    find_fuzzname['possible_new_name'].map(bikeshare_stations.set_index('Station Name')['Station Id']),
    inplace=True)

find_fuzzname
# Out:
#       Station Id                                   Station Name  \
# 833       7161.0                        Beverly St / College St
# 999       7242.0  Lake Shore Blvd W / Ontario Dr(Ontario Place)
# 1049      7249.0            Dovercourt Rd / Harrison St - SMART
# 1051      7488.0         Summerhill Ave / MacLennan Ave - SMART
#
#                                   possible_new_name
# 833                        Beverley St / College St
# 999                  Lake Shore Blvd W / Ontario Dr
# 1049  Dovercourt Rd / Harrison St (Green P) - SMART
# 1051                 Summerhill Ave / Maclennan Ave

# %%
# Now combine the stations_old
stations_old_noID = find_fuzzname.drop(columns='possible_new_name')
stations_old = pd.concat([stations_old_ID, stations_old_noID])

# %%
stations_old.nunique()
# Out:
# Station Id      626
# Station Name    811
# dtype: int64

# %%
stations_old.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 811 entries, 86 to 1051
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Station Id    811 non-null    float64
#  1   Station Name  811 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 19.0+ KB

# %% [markdown]
# The result means that each station name have only one ID, but it's name can be different due to typos or historical reasons. And we are able to find all stations that have station Id here with their messy names.
#
# **Note**: The six stations that have no matching name in `bikeshare_stations` data and no matching station ID was dropped here. Therefore these stations will also be dropped later in ridership data.
#
# In order to have a dataframe that relate all messy station names with new station names using the station ID, we merge the `stations_old` with `bikeshare_stations` to create a new dataframe `stations_merge`.

# %%
# Merge the stations_old with bikeshare_stations
stations_merge = pd.merge(stations_old, 
                          bikeshare_stations, 
                          on='Station Id', 
                          how='left',
                          suffixes=('_messy', '_new')
                         ).drop_duplicates(subset='Station Name_messy')

# %%
stations_merge.head()
# Out:
#    Station Id               Station Name_messy              Station Name_new  \
# 0      7000.0     Fort York  Blvd / Capreol Ct  Fort York  Blvd / Capreol Ct
# 1      7000.0    Fort York  Blvd / Capreol Crt  Fort York  Blvd / Capreol Ct
# 2      7001.0        Wellesley Station Green P     Wellesley Station Green P
# 3      7001.0  Lower Jarvis St / The Esplanade     Wellesley Station Green P
# 4      7002.0       St. George St / Bloor St W    St. George St / Bloor St W
#
#          lat        lon  capacity
# 0  43.639832 -79.395954      35.0
# 1  43.639832 -79.395954      35.0
# 2  43.664964 -79.383550      26.0
# 3  43.664964 -79.383550      26.0
# 4  43.667333 -79.399429      19.0

# %%
stations_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 811 entries, 0 to 810
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Station Id          811 non-null    float64
#  1   Station Name_messy  811 non-null    object
#  2   Station Name_new    747 non-null    object
#  3   lat                 747 non-null    float64
#  4   lon                 747 non-null    float64
#  5   capacity            747 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 44.4+ KB

# %% [markdown]
# We already made sure that each messy station name has its only one ID, but it's possible that some stations are removed now, so we may not have a new station name for them. We need to find these canceled stations.

# %%
# find stations that has no station name related according to station ID
station_is_canceled = stations_merge['Station Name_new'].isnull()
stations_merge[station_is_canceled]
# Out:
#      Station Id                Station Name_messy Station Name_new  lat  lon  \
# 16       7011.0     Wellington St W / Portland St              NaN  NaN  NaN
# 18       7013.0          Scott St / The Esplanade              NaN  NaN  NaN
# 22       7017.0          Widmer St / Adelaide St               NaN  NaN  NaN
# 23       7017.0         Widmer St / Adelaide St W              NaN  NaN  NaN
# 25       7019.0          Temperance St / Yonge St              NaN  NaN  NaN
# ..          ...                               ...              ...  ...  ...
# 762      7638.0             Warehouse EBS-Station              NaN  NaN  NaN
# 777      7649.0  Greenwood Subway Station - SMART              NaN  NaN  NaN
# 778      7649.0          Greenwood Subway Station              NaN  NaN  NaN
# 780      7651.0        Bloor St W / Gladstone Ave              NaN  NaN  NaN
# 781      7653.0            Bloor St W / Indian Rd              NaN  NaN  NaN
#
#      capacity
# 16        NaN
# 18        NaN
# 22        NaN
# 23        NaN
# 25        NaN
# ..        ...
# 762       NaN
# 777       NaN
# 778       NaN
# 780       NaN
# 781       NaN
#
# [64 rows x 6 columns]

# %% [markdown]
# **We can't find a new station name for these stations using their ID, meaning that they are canceled now. So we add a suffix "_canceled" to its name to be the new station name.**

# %%
stations_merge['Station Name_new'].fillna(
        stations_merge['Station Name_messy']+'_canceled',
        inplace=True)

# %%
stations_merge[station_is_canceled]
# Out:
#      Station Id                Station Name_messy  \
# 16       7011.0     Wellington St W / Portland St
# 18       7013.0          Scott St / The Esplanade
# 22       7017.0          Widmer St / Adelaide St
# 23       7017.0         Widmer St / Adelaide St W
# 25       7019.0          Temperance St / Yonge St
# ..          ...                               ...
# 762      7638.0             Warehouse EBS-Station
# 777      7649.0  Greenwood Subway Station - SMART
# 778      7649.0          Greenwood Subway Station
# 780      7651.0        Bloor St W / Gladstone Ave
# 781      7653.0            Bloor St W / Indian Rd
#
#                               Station Name_new  lat  lon  capacity
# 16      Wellington St W / Portland St_canceled  NaN  NaN       NaN
# 18           Scott St / The Esplanade_canceled  NaN  NaN       NaN
# 22           Widmer St / Adelaide St _canceled  NaN  NaN       NaN
# 23          Widmer St / Adelaide St W_canceled  NaN  NaN       NaN
# 25           Temperance St / Yonge St_canceled  NaN  NaN       NaN
# ..                                         ...  ...  ...       ...
# 762             Warehouse EBS-Station_canceled  NaN  NaN       NaN
# 777  Greenwood Subway Station - SMART_canceled  NaN  NaN       NaN
# 778          Greenwood Subway Station_canceled  NaN  NaN       NaN
# 780        Bloor St W / Gladstone Ave_canceled  NaN  NaN       NaN
# 781            Bloor St W / Indian Rd_canceled  NaN  NaN       NaN
#
# [64 rows x 6 columns]

# %% [markdown]
# All the canceled station names are renamed! So these stations can still be used when lat and lon information are not used. When we want to use geographical information, we can also simply filter these stations out. Now let's have a look at the stations_merge dataframe.

# %%
stations_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 811 entries, 0 to 810
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Station Id          811 non-null    float64
#  1   Station Name_messy  811 non-null    object
#  2   Station Name_new    811 non-null    object
#  3   lat                 747 non-null    float64
#  4   lon                 747 non-null    float64
#  5   capacity            747 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 44.4+ KB

# %%
stations_merge.nunique()
# Out:
# Station Id            626
# Station Name_messy    811
# Station Name_new      645
# lat                   579
# lon                   580
# capacity               35
# dtype: int64

# %% [markdown]
# Now we can update names in ridership dataframe using stations_merge. We can create a function `replace_name` to do this repeatedly for different years.
#
# **Note**: Replacing name is more time-consuming than other steps, may take up to a minute for each year.

# %%
# create a replace_name function to update stations names of ridership dataframes.
def replace_name(df):
    """This function replaces the Start Station Name and End Station Name in ridership data.
    using stations_merge as reference.
    
    Input should be a ridership dataframe with columns "Start Station Name" and "End Station Name"
    output is a dataframe.
    """
    
    # List all unique messy names in stations_merge
    unique_messy_merge = stations_merge['Station Name_messy'].unique()
    
    # create a unique_messy_name np array that has all unique names from ridership data.
    unique_messy_start = ridership_est_2017['Start Station Name'].unique()
    unique_messy_end = ridership_est_2017['End Station Name'].unique()
    unique_messy_trip = np.unique(np.concatenate((unique_messy_start, unique_messy_end)))
    
    df_copy = df.copy()
        
    for old_name in unique_messy_trip:
        if old_name in unique_messy_merge:
            new_name = stations_merge[stations_merge['Station Name_messy']==old_name]['Station Name_new'].tolist()[0]
            df_copy.replace({'Start Station Name': old_name, 'End Station Name': old_name}, new_name, inplace=True)
        
    return df_copy

# %%
# Update the names in ridership data
ridership_est_2017 = replace_name(ridership_est_2017)

# %% [markdown]
# **Name replace check**
#
# Check on a pre-existing messy name 'Beverly St / College St' to see if the replace is properly done.

# %%
ridership_est_2017[ridership_est_2017['Start Station Name']=='Beverly St / College St']
# Out:
# Empty DataFrame
# Columns: [Trip Id, Trip Duration, Start Station Id, Start Time, Start Station Name, End Station Id, End Time, End Station Name, User Type]
# Index: []

# %%
ridership_est_2017[ridership_est_2017['Start Station Name']=='Beverley St / College St']
# Out:
#           Trip Id  Trip Duration  Start Station Id                Start Time  \
# 4004040   1485375           1139               NaN 2017-08-01 02:24:00-04:00
# 4005334   1486823            694               NaN 2017-08-01 10:04:00-04:00
# 4005388   1486888            803               NaN 2017-08-01 10:08:00-04:00
# 4005397   1486898            781               NaN 2017-08-01 10:09:00-04:00
# 4005442   1486956            464               NaN 2017-08-01 10:12:00-04:00
# ...           ...            ...               ...                       ...
# 15358736   868483            629            7161.0 2017-03-31 18:20:00-04:00
# 15358819   868570            190            7161.0 2017-03-31 19:20:00-04:00
# 15358820   868569            324            7161.0 2017-03-31 19:20:00-04:00
# 15358963   868734            416            7161.0 2017-03-31 23:25:00-04:00
# 15358971   868743            446            7161.0 2017-03-31 23:44:00-04:00
#
#                 Start Station Name  End Station Id                  End Time  \
# 4004040   Beverley St / College St          7030.0 2017-08-01 02:43:00-04:00
# 4005334   Beverley St / College St          7034.0 2017-08-01 10:15:00-04:00
# 4005388   Beverley St / College St             NaN 2017-08-01 10:22:00-04:00
# 4005397   Beverley St / College St             NaN 2017-08-01 10:22:00-04:00
# 4005442   Beverley St / College St          7053.0 2017-08-01 10:20:00-04:00
# ...                            ...             ...                       ...
# 15358736  Beverley St / College St          7206.0 2017-03-31 18:30:00-04:00
# 15358819  Beverley St / College St          7027.0 2017-03-31 19:23:00-04:00
# 15358820  Beverley St / College St          7102.0 2017-03-31 19:25:00-04:00
# 15358963  Beverley St / College St          7041.0 2017-03-31 23:32:00-04:00
# 15358971  Beverley St / College St          7204.0 2017-03-31 23:52:00-04:00
#
#                                 End Station Name User Type
# 4004040                  Bay St / Wellesley St W    Member
# 4005334                   Church St / Bloor St E    Member
# 4005388   Wellington St W / Portland St_canceled    Member
# 4005397   Wellington St W / Portland St_canceled    Member
# 4005442                         Metro Hall Plaza    Member
# ...                                          ...       ...
# 15358736              Claremont St / Dundas St W    Member
# 15358819              Beverley  St / Dundas St W    Member
# 15358820                   Nelson St / Duncan St    Member
# 15358963                    Edward St / Yonge St    Member
# 15358971                College St / Crawford St    Member
#
# [10258 rows x 9 columns]

# %% [markdown]
# As shown above, the 'Beverley St / College St' with missing station id are the ones that just had their names replace.

# %% [markdown]
# **The replacement was successful!**
#
# Then we can continue to fill missing station ID and clean the data. Here we are creating another function `fill_id_merge` to fill missing station ID using the `stations_merge` so that even for canceled stations, we can find their ID and keep them for further analysis.

# %%
# create a series newname_to_ID to relate all new names to ID (including canceled stations)
stations_newname_to_ID = stations_merge.drop_duplicates(subset=['Station Name_new'])
newname_to_ID = stations_newname_to_ID.set_index('Station Name_new')['Station Id']

# %%
# Create a fill_id_merge function for filling missing station ID according to station name
def fill_id_merge(df):
    """This function is for filling missing station names according to station ID
    Use the stations_merge as reference.
    """
    
    df['Start Station Id'].fillna(
        df['Start Station Name'].map(newname_to_ID),
        inplace=True)
    
    df['End Station Id'].fillna(
        df['End Station Name'].map(newname_to_ID),
        inplace=True)
    
    return df

# %%
# fill missing ID with new station names
fill_id_merge(ridership_est_2017)
# Out:
#           Trip Id  Trip Duration  Start Station Id                Start Time  \
# 4003950   1485285            290            7004.0 2017-08-01 01:00:00-04:00
# 4003951   1485286            311            7197.0 2017-08-01 01:02:00-04:00
# 4003952   1485287           1053            7196.0 2017-08-01 01:02:00-04:00
# 4003953   1485288            502            7107.0 2017-08-01 01:02:00-04:00
# 4003954   1485289            803            7195.0 2017-08-01 01:04:00-04:00
# ...           ...            ...               ...                       ...
# 15358988   868761            577            7021.0 2017-04-01 00:42:00-04:00
# 15358989   868762            292            7069.0 2017-04-01 00:50:00-04:00
# 15358990   868763            709            7010.0 2017-04-01 00:51:00-04:00
# 15358991   868764            699            7058.0 2017-04-01 00:53:00-04:00
# 15358992   868765            572            7047.0 2017-04-01 00:54:00-04:00
#
#                                  Start Station Name  End Station Id  \
# 4003950                     University Ave / Elm St          7007.0
# 4003951                  Queen St W / Dovercourt Rd          7046.0
# 4003952                      Roxton Rd / Harbord St          7128.0
# 4003953                   Cherry St / Distillery Ln          7067.0
# 4003954                     Ulster St / Bathurst St          7163.0
# ...                                             ...             ...
# 15358988                         Bay St / Albert St          7024.0
# 15358989                   Queen St W / Spadina Ave          7037.0
# 15358990                    King St W / Spadina Ave          7060.0
# 15358991                          Huron/ Harbord St          7057.0
# 15358992  University Ave / Gerrard St W (East Side)          7044.0
#
#                           End Time                    End Station Name  \
# 4003950  2017-08-01 01:04:00-04:00               College St / Huron St
# 4003951  2017-08-01 01:07:00-04:00          Niagara St / Richmond St W
# 4003952  2017-08-01 01:19:00-04:00               Yonge St / Aylmer Ave
# 4003953  2017-08-01 01:10:00-04:00               Yonge St / Harbour St
# 4003954  2017-08-01 01:17:00-04:00                  Yonge St / Wood St
# ...                            ...                                 ...
# 15358988 2017-04-01 00:52:00-04:00            Dundonald St / Church St
# 15358989 2017-04-01 00:55:00-04:00           Bathurst St / Dundas St W
# 15358990 2017-04-01 01:02:00-04:00  Princess St / Adelaide St_canceled
# 15358991 2017-04-01 01:04:00-04:00     Simcoe St / Wellington St South
# 15358992 2017-04-01 01:03:00-04:00            Church St / Alexander St
#
#          User Type
# 4003950     Member
# 4003951     Member
# 4003952     Member
# 4003953     Member
# 4003954     Member
# ...            ...
# 15358988    Member
# 15358989    Member
# 15358990    Member
# 15358991    Member
# 15358992    Member
#
# [1378074 rows x 9 columns]

# %%
ridership_est_2017.isnull().sum()
# Out:
# Trip Id                   0
# Trip Duration             0
# Start Station Id      15279
# Start Time                0
# Start Station Name        0
# End Station Id        17685
# End Time                  0
# End Station Name          0
# User Type                 0
# dtype: int64

# %%
#Check again the trips with missing Station Id
ridership_est_2017[
    (ridership_est_2017['Start Station Id'].isnull()==True) | 
    (ridership_est_2017['End Station Id'].isnull()==True)]
# Out:
#           Trip Id  Trip Duration  Start Station Id                Start Time  \
# 4003971   1485306            824               NaN 2017-08-01 01:17:00-04:00
# 4004061   1485396            879            7042.0 2017-08-01 03:28:00-04:00
# 4004064   1485399            536            7040.0 2017-08-01 03:48:00-04:00
# 4004087   1485422            815               NaN 2017-08-01 06:05:00-04:00
# 4004100   1485433            474            7055.0 2017-08-01 06:38:00-04:00
# ...           ...            ...               ...                       ...
# 12504959  1485066            974               NaN 2017-07-31 23:23:00-04:00
# 12505029  1485136            611               NaN 2017-07-31 23:45:00-04:00
# 12505127  1485234           1219            7033.0 2017-08-01 00:31:00-04:00
# 12505134  1485241           1184            7033.0 2017-08-01 00:32:00-04:00
# 12505148  1485255            266            7162.0 2017-08-01 00:38:00-04:00
#
#                           Start Station Name  End Station Id  \
# 4003971   Michael Sweet Ave / St. Patrick St          7175.0
# 4004061       Sherbourne St / Wellesley St E             NaN
# 4004064              Euclid Ave / Bloor St W             NaN
# 4004087          Margueretta St / College St          7151.0
# 4004100               Jarvis St / Carlton St             NaN
# ...                                      ...             ...
# 12504959            Lansdowne Subway Green P          7188.0
# 12505029  Michael Sweet Ave / St. Patrick St          7105.0
# 12505127                       Union Station             NaN
# 12505134                       Union Station             NaN
# 12505148            Hayter St / Laplante Ave             NaN
#
#                           End Time                    End Station Name  \
# 4003971  2017-08-01 01:31:00-04:00            HTO Park (Queens Quay W)
# 4004061  2017-08-01 03:43:00-04:00  Michael Sweet Ave / St. Patrick St
# 4004064  2017-08-01 03:56:00-04:00            Lansdowne Subway Green P
# 4004087  2017-08-01 06:19:00-04:00      Essex St / Christie St - SMART
# 4004100  2017-08-01 06:46:00-04:00  Michael Sweet Ave / St. Patrick St
# ...                            ...                                 ...
# 12504959 2017-07-31 23:39:00-04:00        Exhibition GO (Atlantic Ave)
# 12505029 2017-07-31 23:55:00-04:00           Queen St E / Sackville St
# 12505127 2017-08-01 00:51:00-04:00  Michael Sweet Ave / St. Patrick St
# 12505134 2017-08-01 00:51:00-04:00  Michael Sweet Ave / St. Patrick St
# 12505148 2017-08-01 00:42:00-04:00  Michael Sweet Ave / St. Patrick St
#
#          User Type
# 4003971     Casual
# 4004061     Member
# 4004064     Member
# 4004087     Member
# 4004100     Member
# ...            ...
# 12504959    Member
# 12505029    Member
# 12505127    Casual
# 12505134    Casual
# 12505148    Member
#
# [32635 rows x 9 columns]

# %% [markdown]
# **These are the stations that's identified before that are not related to any station ID and they are probably early canceled stations. Supposedly these stations are removed because they are less used. Also, removing these rows only causes 2.37% loss of information. So we simply drop them.**

# %%
ridership_2017_clean = ridership_est_2017.dropna()

# %%
ridership_2017_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1345439 entries, 4003950 to 15358992
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip Id             1345439 non-null  int64
#  1   Trip Duration       1345439 non-null  int64
#  2   Start Station Id    1345439 non-null  float64
#  3   Start Time          1345439 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name  1345439 non-null  object
#  5   End Station Id      1345439 non-null  float64
#  6   End Time            1345439 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name    1345439 non-null  object
#  8   User Type           1345439 non-null  object
# dtypes: datetime64[ns, US/Eastern](2), float64(2), int64(2), object(3)
# memory usage: 102.6+ MB

# %% [markdown]
# **Conclusion:** The 2017 data contains a lot of missing Station Id since July possibly due to station name updating. This can be largely fixed by finding their station Id using the updated name of each stations. The information loss for removing outliers and stations with no station Id are less than 10% in total.

# %% [markdown]
# #### **2018 Data**

# %% [markdown]
# We can start with a similar workflow for cleaning 2018 ridership data.

# %%
ridership_est_2018 = time_convert(ridership_2018)

# %%
plot_distribution('Trip Duration', ridership_est_2018)

# %%
ridership_est_2018 = remove_outliers(ridership_est_2018)
# Out:
# Percent of outliers removed: 5.0232325937559335%

# %%
plot_distribution('Trip Duration', ridership_est_2018)

# %%
ridership_est_2018.isnull().sum()
# Out:
# Trip Id                0
# Trip Duration          0
# Start Station Id      54
# Start Time             0
# Start Station Name     0
# End Station Id        54
# End Time               0
# End Station Name       0
# User Type              0
# dtype: int64

# %% [markdown]
# The station names may need cleaning.

# %%
ridership_est_2018 = replace_name(ridership_est_2018)

# %%
# fill missing ID with new station names
fill_id_merge(ridership_est_2018)
# Out:
#           Trip Id  Trip Duration  Start Station Id                Start Time  \
# 3899663   4357633            167            7089.0 2018-11-01 01:01:00-04:00
# 3899664   4357634            461            7260.0 2018-11-01 01:03:00-04:00
# 3899665   4357635            604            7281.0 2018-11-01 01:03:00-04:00
# 3899666   4357637           1133            7047.0 2018-11-01 01:06:00-04:00
# 3899667   4357638            753            7032.0 2018-11-01 01:07:00-04:00
# ...           ...            ...               ...                       ...
# 10871422  4158587           1724            7195.0 2018-10-01 00:47:00-04:00
# 10871423  4158588           1632            7195.0 2018-10-01 00:49:00-04:00
# 10871424  4158589            162            7121.0 2018-10-01 00:53:00-04:00
# 10871425  4158590            474            7140.0 2018-10-01 00:53:00-04:00
# 10871426  4158591            500            7037.0 2018-10-01 00:54:00-04:00
#
#                          Start Station Name  End Station Id  \
# 3899663                Church St  / Wood St          7077.0
# 3899664         Spadina Ave / Adelaide St W          7333.0
# 3899665   Charles St W / Balmuto St - SMART          7002.0
# 3899666       University Ave / Gerrard St W          7140.0
# 3899667           Augusta Ave / Dundas St W          7210.0
# ...                                     ...             ...
# 10871422            Ulster St / Bathurst St          7195.0
# 10871423            Ulster St / Bathurst St          7195.0
# 10871424            Jarvis St / Dundas St E          7038.0
# 10871425        Macpherson Ave / Spadina Rd          7281.0
# 10871426          Bathurst St / Dundas St W          7239.0
#
#                           End Time                          End Station Name  \
# 3899663  2018-11-01 01:04:00-04:00                        College Park South
# 3899664  2018-11-01 01:11:00-04:00                   King St E / Victoria St
# 3899665  2018-11-01 01:13:00-04:00                St. George St / Bloor St W
# 3899666  2018-11-01 01:25:00-04:00               Macpherson Ave / Spadina Rd
# 3899667  2018-11-01 01:20:00-04:00  Mary McCormick Rec Centre (Sheridan Ave)
# ...                            ...                                       ...
# 10871422 2018-10-01 01:16:00-04:00                   Ulster St / Bathurst St
# 10871423 2018-10-01 01:16:00-04:00                   Ulster St / Bathurst St
# 10871424 2018-10-01 00:55:00-04:00                    Dundas St W / Yonge St
# 10871425 2018-10-01 01:01:00-04:00         Charles St W / Balmuto St - SMART
# 10871426 2018-10-01 01:02:00-04:00          Bloor St W / Manning Ave - SMART
#
#          User Type
# 3899663     Member
# 3899664     Member
# 3899665     Member
# 3899666     Member
# 3899667     Member
# ...            ...
# 10871422    Member
# 10871423    Member
# 10871424    Member
# 10871425    Member
# 10871426    Member
#
# [1826351 rows x 9 columns]

# %%
ridership_est_2018.isnull().sum()
# Out:
# Trip Id                0
# Trip Duration          0
# Start Station Id      17
# Start Time             0
# Start Station Name     0
# End Station Id        12
# End Time               0
# End Station Name       0
# User Type              0
# dtype: int64

# %%
print("Percent of information loss for drop missing values is about: {}".format(17 / len(ridership_est_2018) * 100))
# Out:
# Percent of information loss for drop missing values is about: 0.000930817789132538

# %%
ridership_2018_clean = ridership_est_2018.dropna()

# %%
ridership_2018_clean.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1826328 entries, 3899663 to 10871426
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip Id             1826328 non-null  int64
#  1   Trip Duration       1826328 non-null  int64
#  2   Start Station Id    1826328 non-null  float64
#  3   Start Time          1826328 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name  1826328 non-null  object
#  5   End Station Id      1826328 non-null  float64
#  6   End Time            1826328 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name    1826328 non-null  object
#  8   User Type           1826328 non-null  object
# dtypes: datetime64[ns, US/Eastern](2), float64(2), int64(2), object(3)
# memory usage: 139.3+ MB

# %% [markdown]
# **Conclusion:** The 2018 ridership data is rather clean. The missing station Id can also be mostly filled using `fill_id_merge`. The information loss after cleaning is about 5%.

# %% [markdown]
# #### **2019 Data**

# %% [markdown]
# For 2019 ridership data, the time changed since a certain months, and have two formats, so we need to split the dataframe again to convert time.

# %%
ridership_2019_UTC = ridership_2019.loc[ridership_2019['Start Time'].str.contains('UTC')]
ridership_2019_EST = ridership_2019.loc[ridership_2019['Start Time'].str.contains('EST')]

# %%
ridership_est_2019 = pd.concat([time_convert(ridership_2019_UTC), time_convert(ridership_2019_EST)])

# %%
plot_distribution('Trip Duration', ridership_est_2019)

# %%
ridership_est_2019 = remove_outliers(ridership_est_2019)
# Out:
# Percent of outliers removed: 4.5134762785279285%

# %%
plot_distribution('Trip Duration', ridership_est_2019)

# %%
ridership_est_2019.isnull().sum()
# Out:
# Trip Id                 0
# Trip Duration           0
# Start Station Id        0
# Start Time              0
# Start Station Name      0
# End Station Id        392
# End Time                0
# End Station Name      392
# User Type               0
# dtype: int64

# %%
# Examine the rows with missing station Id and station name
empty_2019 = ridership_est_2019[
    (ridership_est_2019['End Station Name'].isnull()==True) | 
    (ridership_est_2019['End Station Id'].isnull()==True)]
empty_2019.head()
# Out:
#           Trip Id  Trip Duration  Start Station Id                Start Time  \
# 5010921   5370500            696            7228.0 2019-06-17 13:21:00-04:00
# 11326687  7236682            900            7255.0 2019-12-01 19:59:00-05:00
# 11326953  7237060           1224            7211.0 2019-12-02 08:58:00-05:00
# 11326982  7237090           1551            7470.0 2019-12-02 09:13:00-05:00
# 11326995  7237105            448            7101.0 2019-12-02 09:19:00-05:00
#
#                            Start Station Name  End Station Id  \
# 5010921         Queen St W / Roncesvalles Ave             NaN
# 11326687    Stewart St / Bathurst St  - SMART             NaN
# 11326953         Fort York Blvd / Garrison Rd             NaN
# 11326982          York St / Lake Shore Blvd W             NaN
# 11326995  Lower Sherbourne St / The Esplanade             NaN
#
#                           End Time End Station Name User Type
# 5010921  2019-06-17 13:32:00-04:00              NaN    Member
# 11326687 2019-12-01 20:14:00-05:00              NaN    Member
# 11326953 2019-12-02 09:18:00-05:00              NaN    Member
# 11326982 2019-12-02 09:39:00-05:00              NaN    Member
# 11326995 2019-12-02 09:27:00-05:00              NaN    Member

# %% [markdown]
# These trips lost All end station information and will not be useful for further analysis. Let's find out when this error occurred.

# %%
# Visualize the error trips counts among different months.
empty_2019['Month'] = empty_2019['Start Time'].dt.month
sns.countplot(data=empty_2019, x='Month', hue='User Type')
plt.show()

# %% [markdown]
# It seems that this error greatly increased since September 2019, and happens more for annual members than casual users. And it was not solved until the end of year, so this can still happen for the 2020 data.

# %%
print("Percent of information loss for drop missing values: {}".format(392 /len(ridership_est_2019) * 100))
# Out:
# Percent of information loss for drop missing values: 0.016827840460052552

# %% [markdown]
# It's clear that these rows should be dropped, and they only cause around 0.017% of information loss.

# %%
ridership_est_2019 = ridership_est_2019.dropna()

# %%
ridership_2019_clean = replace_name(ridership_est_2019)

# %%
ridership_2019_clean.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329081 entries, 5644119 to 13253294
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip Id             2329081 non-null  int64
#  1   Trip Duration       2329081 non-null  int64
#  2   Start Station Id    2329081 non-null  float64
#  3   Start Time          2329081 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name  2329081 non-null  object
#  5   End Station Id      2329081 non-null  float64
#  6   End Time            2329081 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name    2329081 non-null  object
#  8   User Type           2329081 non-null  object
# dtypes: datetime64[ns, US/Eastern](2), float64(2), int64(2), object(3)
# memory usage: 177.7+ MB

# %% [markdown]
# **Conclusion:** Even though 2019 data has some trips that have no end station information. The ridership data for 2019 is still rather clean. The information loss after cleaning is still less than 5%.

# %% [markdown]
# #### **2020 Data**

# %%
ridership_est_2020 = time_convert(ridership_2020)

# %%
plot_distribution('Trip Duration', ridership_est_2020)

# %%
ridership_est_2020 = remove_outliers(ridership_est_2020)
# Out:
# Percent of outliers removed: 4.311910660088181%

# %%
plot_distribution('Trip Duration', ridership_est_2020)

# %%
ridership_est_2020.isnull().sum()
# Out:
# Trip Id                  0
# Trip Duration            0
# Start Station Id         0
# Start Time               0
# Start Station Name     772
# End Station Id         396
# End Time                 0
# End Station Name      1119
# User Type                0
# dtype: int64

# %%
ridership_est_2020 = replace_name(ridership_est_2020)

# %%
fill_id_merge(ridership_est_2020)
fill_name(ridership_est_2020)
# Out:
#           Trip Id  Trip Duration  Start Station Id                Start Time  \
# 741770    7774422            212            7045.0 2020-05-01 00:02:00-04:00
# 741771    7774423            939            7206.0 2020-05-01 00:04:00-04:00
# 741772    7774424            858            7198.0 2020-05-01 00:07:00-04:00
# 741773    7774425            244            7372.0 2020-05-01 00:07:00-04:00
# 741774    7774426            689            7361.0 2020-05-01 00:08:00-04:00
# ...           ...            ...               ...                       ...
# 15310025  9476679            938            7154.0 2020-08-31 23:59:00-04:00
# 15310026  9476681            592            7012.0 2020-08-31 23:59:00-04:00
# 15310027  9476682            843            7076.0 2020-08-31 23:59:00-04:00
# 15310028  9476683            420            7038.0 2020-08-31 23:59:00-04:00
# 15310029  9476684           1173            7514.0 2020-08-31 23:59:00-04:00
#
#                                  Start Station Name  End Station Id  \
# 741770                         Bond St / Queen St E          7041.0
# 741771                   Claremont St / Dundas St W          7383.0
# 741772                       Queen St W / Cowan Ave          7323.0
# 741773                      King St W / Portland St          7046.0
# 741774                      Hocken Ave./Vaughan Rd.          7369.0
# ...                                             ...             ...
# 15310025                    Bathurst Subway Station          7238.0
# 15310026    Elizabeth St / Edward St (Bus Terminal)          7100.0
# 15310027                    York St / Queens Quay W          7041.0
# 15310028                     Dundas St W / Yonge St          7044.0
# 15310029  Humber Bay Shores Park / Marine Parade Dr          7514.0
#
#                           End Time                           End Station Name  \
# 741770   2020-05-01 00:05:00-04:00                       Edward St / Yonge St
# 741771   2020-05-01 00:19:00-04:00                              12 Harbour St
# 741772   2020-05-01 00:21:00-04:00                 457 King St. W. at Spadina
# 741773   2020-05-01 00:11:00-04:00                 Niagara St / Richmond St W
# 741774   2020-05-01 00:20:00-04:00              Dupont St / Emerson Ave SMART
# ...                            ...                                        ...
# 15310025 2020-09-01 00:15:00-04:00  Sorauren/Geoffrey (Sorauren Park) - SMART
# 15310026 2020-09-01 00:09:00-04:00             Dundas St E / Regent Park Blvd
# 15310027 2020-09-01 00:13:00-04:00                       Edward St / Yonge St
# 15310028 2020-09-01 00:06:00-04:00                   Church St / Alexander St
# 15310029 2020-09-01 00:19:00-04:00  Humber Bay Shores Park / Marine Parade Dr
#
#          User Type
# 741770      Member
# 741771      Member
# 741772      Member
# 741773      Member
# 741774      Member
# ...            ...
# 15310025    Member
# 15310026    Member
# 15310027    Casual
# 15310028    Member
# 15310029    Casual
#
# [2785775 rows x 9 columns]

# %%
ridership_est_2020.isnull().sum()
# Out:
# Trip Id                 0
# Trip Duration           0
# Start Station Id        0
# Start Time              0
# Start Station Name      0
# End Station Id        396
# End Time                0
# End Station Name      396
# User Type               0
# dtype: int64

# %% [markdown]
# The 2020 ridership data have some missing station names that can be filled using their station Id, which leaves us with some trips that have no end station information at all again. This means the problem continued since 2019.

# %%
# Examine the rows with missing station Id and station name
empty_2020 = ridership_est_2020[
    (ridership_est_2020['End Station Name'].isnull()==True) | 
    (ridership_est_2020['End Station Id'].isnull()==True)]
empty_2020.head()
# Out:
#         Trip Id  Trip Duration  Start Station Id                Start Time  \
# 742130  7775292            559            7042.0 2020-05-01 10:27:00-04:00
# 745038  7778789           1685            7409.0 2020-05-01 19:32:00-04:00
# 745173  7778936            964            7424.0 2020-05-01 19:48:00-04:00
# 746226  7780393            540            7285.0 2020-05-02 09:49:00-04:00
# 753968  7789397            600            7016.0 2020-05-03 13:46:00-04:00
#
#                              Start Station Name  End Station Id  \
# 742130           Sherbourne St / Wellesley St E             NaN
# 745038                  Isabella St / Church St             NaN
# 745173            Merton St / Mount Pleasant Rd             NaN
# 746226         Spadina Ave / Harbord St - SMART             NaN
# 753968  Bay St / Queens Quay W (Ferry Terminal)             NaN
#
#                         End Time End Station Name User Type
# 742130 2020-05-01 10:36:00-04:00              NaN    Member
# 745038 2020-05-01 20:00:00-04:00              NaN    Member
# 745173 2020-05-01 20:04:00-04:00              NaN    Casual
# 746226 2020-05-02 09:58:00-04:00              NaN    Member
# 753968 2020-05-03 13:56:00-04:00              NaN    Casual

# %%
# Visualize the error trips counts among different months.
empty_2020['Month'] = empty_2020['Start Time'].dt.month
sns.countplot(data=empty_2020, x='Month', hue='User Type')
plt.show()

# %% [markdown]
# So the error counts decreased after June, so probably the city have found a solution for this issue.

# %%
print("Percent of information loss for drop missing values: {}".format(396 /len(ridership_est_2020) * 100))
# Out:
# Percent of information loss for drop missing values: 0.014215074799651804

# %% [markdown]
# It's clear that these rows with neither End Station Id or End Station Name should be dropped, and they only cause around 0.014% of information loss.

# %%
ridership_2020_clean = ridership_est_2020.dropna()

# %%
ridership_2020_clean.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2785379 entries, 741770 to 15310029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip Id             2785379 non-null  int64
#  1   Trip Duration       2785379 non-null  int64
#  2   Start Station Id    2785379 non-null  float64
#  3   Start Time          2785379 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name  2785379 non-null  object
#  5   End Station Id      2785379 non-null  float64
#  6   End Time            2785379 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name    2785379 non-null  object
#  8   User Type           2785379 non-null  object
# dtypes: datetime64[ns, US/Eastern](2), float64(2), int64(2), object(3)
# memory usage: 212.5+ MB

# %% [markdown]
# **Conclusion:** The 2020 data is rather clean. The information loss after clean is less than 4.5%.

# %% [markdown]
# #### **2021 Data**

# %%
ridership_est_2021 = time_convert(ridership_2021)

# %%
plot_distribution('Trip Duration', ridership_est_2021)

# %%
ridership_est_2021 = remove_outliers(ridership_est_2021)
# Out:
# Percent of outliers removed: 3.845202845617368%

# %%
plot_distribution('Trip Duration', ridership_est_2021)

# %%
ridership_est_2021.isnull().sum()
# Out:
# Trip Id                  0
# Trip Duration            0
# Start Station Id         0
# Start Time               0
# Start Station Name    3596
# End Station Id          47
# End Time                 0
# End Station Name      3886
# User Type                0
# dtype: int64

# %% [markdown]
# Let's find out when the missing name error occurred.

# %%
empty_2021 = ridership_est_2021[
    (ridership_est_2021['Start Station Name'].isnull()==True) |
    (ridership_est_2021['End Station Name'].isnull()==True)
]
empty_2021.head()
# Out:
#           Trip Id  Trip Duration  Start Station Id                Start Time  \
# 6337946  11784118           1793            7021.0 2021-06-01 21:30:00-04:00
# 7301263  12739271            607            7069.0 2021-07-27 07:46:00-04:00
# 7457631  11381545           1550            7455.0 2021-05-10 10:46:00-04:00
# 7659846  11611241           1405            7261.0 2021-05-23 12:49:00-04:00
# 7704554  11662155           1082            7463.0 2021-05-25 06:56:00-04:00
#
#                                    Start Station Name  End Station Id  \
# 6337946                            Bay St / Albert St             NaN
# 7301263                      Queen St W / Spadina Ave             NaN
# 7457631  E.T. Seton Park (Eglinton Ave E / Leslie St)             NaN
# 7659846           Queens Quay E / Lower Sherbourne St             NaN
# 7704554                      Adelaide St W / Brant St             NaN
#
#                          End Time End Station Name User Type
# 6337946 2021-06-01 22:00:00-04:00              NaN    Member
# 7301263 2021-07-27 07:56:00-04:00              NaN    Member
# 7457631 2021-05-10 11:12:00-04:00              NaN    Casual
# 7659846 2021-05-23 13:12:00-04:00              NaN    Casual
# 7704554 2021-05-25 07:14:00-04:00              NaN    Casual

# %%
# Visualize the error trips counts among different months.
empty_2021['Month'] = empty_2021['Start Time'].dt.month
sns.countplot(data=empty_2021, x='Month', hue='User Type')
plt.show()

# %% [markdown]
# It seems that this type of error sharply increased since September, and many still have their station Id even without a station name. That could be due to station name updating. And these missing values should be solved easily using `fill_name`.

# %%
ridership_est_2021 = replace_name(ridership_est_2021)

# %%
fill_id_merge(ridership_est_2021)
fill_name(ridership_est_2021)
# Out:
#            Trip Id  Trip Duration  Start Station Id                Start Time  \
# 6325048   11768884            831            7430.0 2021-06-01 00:00:00-04:00
# 6325049   11768885            666            7054.0 2021-06-01 00:00:00-04:00
# 6325050   11768886            453            7576.0 2021-06-01 00:00:00-04:00
# 6325051   11768887            951            7430.0 2021-06-01 00:00:00-04:00
# 6325052   11768888           1130            7171.0 2021-06-01 00:01:00-04:00
# ...            ...            ...               ...                       ...
# 11905542  13392696            455            7054.0 2021-08-31 23:59:00-04:00
# 11905543  13392697            502            7167.0 2021-08-31 23:59:00-04:00
# 11905544  13392699            576            7406.0 2021-08-31 23:59:00-04:00
# 11905545  13392700            840            7458.0 2021-08-31 23:59:00-04:00
# 11905546  13392701           1206            7283.0 2021-08-31 23:59:00-04:00
#
#                                      Start Station Name  End Station Id  \
# 6325048                  Marilyn Bell Park Tennis Court          7171.0
# 6325049                  Navy Wharf Ct. / Bremner Blvd.          7493.0
# 6325050                     Front St E / Bayview Avenue          7261.0
# 6325051                  Marilyn Bell Park Tennis Court          7171.0
# 6325052   Ontario Place Blvd / Lake Shore Blvd W (East)          7411.0
# ...                                                 ...             ...
# 11905542                 Navy Wharf Ct. / Bremner Blvd.          7426.0
# 11905543             Queen St E / George St (Moss Park)          7389.0
# 11905544                       Victoria St / Queen St E          7298.0
# 11905545                         Church St / Lombard St          7199.0
# 11905546               Front St W / Bay St (South Side)          7336.0
#
#                           End Time  \
# 6325048  2021-06-01 00:14:00-04:00
# 6325049  2021-06-01 00:11:00-04:00
# 6325050  2021-06-01 00:08:00-04:00
# 6325051  2021-06-01 00:16:00-04:00
# 6325052  2021-06-01 00:20:00-04:00
# ...                            ...
# 11905542 2021-09-01 00:06:00-04:00
# 11905543 2021-09-01 00:07:00-04:00
# 11905544 2021-09-01 00:09:00-04:00
# 11905545 2021-09-01 00:13:00-04:00
# 11905546 2021-09-01 00:19:00-04:00
#
#                                        End Station Name User Type
# 6325048   Ontario Place Blvd / Lake Shore Blvd W (East)    Casual
# 6325049              Sackville St / Eastern Ave - SMART    Member
# 6325050             Queens Quay E / Lower Sherbourne St    Member
# 6325051   Ontario Place Blvd / Lake Shore Blvd W (East)    Casual
# 6325052                              Little Norway Park    Casual
# ...                                                 ...       ...
# 11905542             Fleet St / Garrison Rd (Fort York)    Member
# 11905543                 College Park- Gerrard Entrance    Member
# 11905544                    Bathurst St / Adelaide St W    Member
# 11905545                        College St / Markham St    Casual
# 11905546                          Queen St E / Alton Av    Casual
#
# [3437709 rows x 9 columns]

# %%
ridership_est_2021.isnull().sum()
# Out:
# Trip Id                0
# Trip Duration          0
# Start Station Id       0
# Start Time             0
# Start Station Name     0
# End Station Id        47
# End Time               0
# End Station Name      47
# User Type              0
# dtype: int64

# %% [markdown]
# So the remaining missing values can only cause insignificant loss of information and should be dropped since they don't have any end station information.

# %%
ridership_2021_clean = ridership_est_2021.dropna()

# %%
ridership_2021_clean.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3437662 entries, 6325048 to 11905546
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip Id             3437662 non-null  int64
#  1   Trip Duration       3437662 non-null  int64
#  2   Start Station Id    3437662 non-null  float64
#  3   Start Time          3437662 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name  3437662 non-null  object
#  5   End Station Id      3437662 non-null  float64
#  6   End Time            3437662 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name    3437662 non-null  object
#  8   User Type           3437662 non-null  object
# dtypes: datetime64[ns, US/Eastern](2), float64(2), int64(2), object(3)
# memory usage: 262.3+ MB

# %% [markdown]
# **Conclusion:** The 2021 data contains some missing stations names, but can be mostly imputed using their station id. So the information loss after data cleaning is less than 4%.

# %% [markdown]
# #### **2022 Data**

# %%
ridership_est_2022 = time_convert(ridership_2022)

# %%
plot_distribution('Trip Duration', ridership_est_2022)

# %%
ridership_est_2022 = remove_outliers(ridership_est_2022)
# Out:
# Percent of outliers removed: 3.619192606726662%

# %%
plot_distribution('Trip Duration', ridership_est_2022)

# %%
ridership_est_2022.isnull().sum()
# Out:
# Trip Id                   0
# Trip Duration             0
# Start Station Id          0
# Start Time                0
# Start Station Name    88783
# End Station Id           14
# End Time                  0
# End Station Name      89757
# User Type                 0
# dtype: int64

# %% [markdown]
# 2022 Ridership data is having a similar problem as the 2021 data.

# %%
empty_2022 = ridership_est_2022[
    (ridership_est_2022['Start Station Name'].isnull()==True) |
    (ridership_est_2022['End Station Name'].isnull()==True)
]
empty_2022.head()
# Out:
#       Trip Id  Trip Duration  Start Station Id                Start Time  \
# 25   16734230            477            7074.0 2022-07-01 00:02:00-04:00
# 93   16734310            758            7684.0 2022-07-01 00:09:00-04:00
# 144  16734371            464            7682.0 2022-07-01 00:14:00-04:00
# 146  16734373            578            7026.0 2022-07-01 00:14:00-04:00
# 147  16734374            580            7184.0 2022-07-01 00:15:00-04:00
#
#              Start Station Name  End Station Id                  End Time  \
# 25        King St E / Church St          7683.0 2022-07-01 00:10:00-04:00
# 93                          NaN          7668.0 2022-07-01 00:22:00-04:00
# 144                         NaN          7054.0 2022-07-01 00:22:00-04:00
# 146      Bay St / St. Joseph St          7710.0 2022-07-01 00:24:00-04:00
# 147  Ossington Ave / College St          7687.0 2022-07-01 00:24:00-04:00
#
#                     End Station Name User Type
# 25                               NaN    Casual
# 93   Simcoe St / Dundas St W - SMART    Casual
# 144   Navy Wharf Ct. / Bremner Blvd.    Casual
# 146                              NaN    Casual
# 147                              NaN    Member

# %%
# Visualize the error trips counts among different months.
empty_2022['Month'] = empty_2022['Start Time'].dt.month
sns.countplot(data=empty_2022, x='Month', hue='User Type')
plt.show()

# %% [markdown]
# It seems that this problem increases since April. And should be fixed now if haven't.

# %%
ridership_est_2022 = replace_name(ridership_est_2022)

# %%
fill_name(ridership_est_2022)
# Out:
#            Trip Id  Trip Duration  Start Station Id                Start Time  \
# 0         16734202           1602            7216.0 2022-07-01 00:00:00-04:00
# 1         16734203            990            7033.0 2022-07-01 00:00:00-04:00
# 2         16734204            653            7184.0 2022-07-01 00:00:00-04:00
# 3         16734205            811            7199.0 2022-07-01 00:00:00-04:00
# 4         16734206           1003            7033.0 2022-07-01 00:00:00-04:00
# ...            ...            ...               ...                       ...
# 14291701  18317445           1670            7100.0 2022-08-31 23:58:00-04:00
# 14291702  18317447            574            7245.0 2022-08-31 23:58:00-04:00
# 14291703  18317448            533            7257.0 2022-08-31 23:59:00-04:00
# 14291704  18317449            615            7368.0 2022-08-31 23:59:00-04:00
# 14291705  18317450           1820            7536.0 2022-08-31 23:59:00-04:00
#
#                          Start Station Name  End Station Id  \
# 0             Wellington St W / Stafford St          7203.0
# 1                             Union Station          7474.0
# 2                Ossington Ave / College St          7368.0
# 3                   College St / Markham St          7533.0
# 4                             Union Station          7474.0
# ...                                     ...             ...
# 14291701     Dundas St E / Regent Park Blvd          7322.0
# 14291702  Tecumseth St / Queen St W - SMART          7069.0
# 14291703       Dundas St W / St. Patrick St          7037.0
# 14291704        Lisgar St / Dundas St SMART          7521.0
# 14291705       Palmerston Ave / Dundas St W          7216.0
#
#                           End Time  \
# 0        2022-07-01 00:26:00-04:00
# 1        2022-07-01 00:16:00-04:00
# 2        2022-07-01 00:11:00-04:00
# 3        2022-07-01 00:13:00-04:00
# 4        2022-07-01 00:17:00-04:00
# ...                            ...
# 14291701 2022-09-01 00:26:00-04:00
# 14291702 2022-09-01 00:08:00-04:00
# 14291703 2022-09-01 00:08:00-04:00
# 14291704 2022-09-01 00:09:00-04:00
# 14291705 2022-09-01 00:29:00-04:00
#
#                                        End Station Name User Type
# 0         Bathurst St/Queens Quay(Billy Bishop Airport)    Casual
# 1                                       Clarence Square    Casual
# 2                           Lisgar St / Dundas St SMART    Member
# 3                            Housey St / Dan Leckie Way    Member
# 4                                       Clarence Square    Casual
# ...                                                 ...       ...
# 14291701                           King St W / Brant St    Casual
# 14291702                       Queen St W / Spadina Ave    Member
# 14291703                      Bathurst St / Dundas St W    Casual
# 14291704                       Emerson Ave / Bloor St W    Casual
# 14291705                  Wellington St W / Stafford St    Casual
#
# [2908447 rows x 9 columns]

# %%
ridership_est_2022.isnull().sum()
# Out:
# Trip Id                 0
# Trip Duration           0
# Start Station Id        0
# Start Time              0
# Start Station Name    581
# End Station Id         14
# End Time                0
# End Station Name      621
# User Type               0
# dtype: int64

# %% [markdown]
# Drop the rows with NA data. They only cause insignificant loss of information.

# %%
ridership_2022_clean = ridership_est_2022.dropna()

# %%
ridership_2022_clean.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2907271 entries, 0 to 14291705
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Trip Id             2907271 non-null  int64
#  1   Trip Duration       2907271 non-null  int64
#  2   Start Station Id    2907271 non-null  float64
#  3   Start Time          2907271 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name  2907271 non-null  object
#  5   End Station Id      2907271 non-null  float64
#  6   End Time            2907271 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name    2907271 non-null  object
#  8   User Type           2907271 non-null  object
# dtypes: datetime64[ns, US/Eastern](2), float64(2), int64(2), object(3)
# memory usage: 221.8+ MB

# %% [markdown]
# ### Concat the ridership data

# %%
ridership_clean = pd.concat([
    ridership_2017_clean,
    ridership_2018_clean,
    ridership_2019_clean,
    ridership_2020_clean,
    ridership_2021_clean,
    ridership_2022_clean
])

# %%
ridership_clean.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14631160 entries, 4003950 to 14291705
# Data columns (total 9 columns):
#  #   Column              Non-Null Count     Dtype
# ---  ------              --------------     -----
#  0   Trip Id             14631160 non-null  int64
#  1   Trip Duration       14631160 non-null  int64
#  2   Start Station Id    14631160 non-null  float64
#  3   Start Time          14631160 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name  14631160 non-null  object
#  5   End Station Id      14631160 non-null  float64
#  6   End Time            14631160 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name    14631160 non-null  object
#  8   User Type           14631160 non-null  object
# dtypes: datetime64[ns, US/Eastern](2), float64(2), int64(2), object(3)
# memory usage: 1.1+ GB

# %%
ridership_clean.isnull().sum()
# Out:
# Trip Id               0
# Trip Duration         0
# Start Station Id      0
# Start Time            0
# Start Station Name    0
# End Station Id        0
# End Time              0
# End Station Name      0
# User Type             0
# dtype: int64

# %% [markdown]
# ## Merge the weather data with bike share trip data

# %%
weather_clean.head()
# Out:
#                            Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# Date/Time
# 2021-11-01 00:00:00-04:00        9.3                  3.1         65.0
# 2021-11-01 01:00:00-04:00        8.5                  3.1         69.0
# 2021-11-01 02:00:00-04:00        8.0                  1.4         63.0
# 2021-11-01 03:00:00-04:00        7.7                  1.1         63.0
# 2021-11-01 04:00:00-04:00        7.0                  0.7         64.0
#
#                            Precip. Amount (mm)  Wind Dir (10s deg)  \
# Date/Time
# 2021-11-01 00:00:00-04:00                  0.0                29.0
# 2021-11-01 01:00:00-04:00                  0.0                28.0
# 2021-11-01 02:00:00-04:00                  0.0                29.0
# 2021-11-01 03:00:00-04:00                  0.0                28.0
# 2021-11-01 04:00:00-04:00                  0.0                27.0
#
#                            Wind Spd (km/h)  Visibility (km)  Hmdx  Wind Chill  \
# Date/Time
# 2021-11-01 00:00:00-04:00             30.0             16.1   NaN         NaN
# 2021-11-01 01:00:00-04:00             24.0             16.1   NaN         NaN
# 2021-11-01 02:00:00-04:00             28.0             16.1   NaN         NaN
# 2021-11-01 03:00:00-04:00             24.0             16.1   NaN         NaN
# 2021-11-01 04:00:00-04:00             21.0             16.1   NaN         NaN
#
#                           Weather
# Date/Time
# 2021-11-01 00:00:00-04:00   Clear
# 2021-11-01 01:00:00-04:00   Clear
# 2021-11-01 02:00:00-04:00   Clear
# 2021-11-01 03:00:00-04:00   Clear
# 2021-11-01 04:00:00-04:00   Clear

# %%
ridership_clean.head()
# Out:
#          Trip Id  Trip Duration  Start Station Id                Start Time  \
# 4003950  1485285            290            7004.0 2017-08-01 01:00:00-04:00
# 4003951  1485286            311            7197.0 2017-08-01 01:02:00-04:00
# 4003952  1485287           1053            7196.0 2017-08-01 01:02:00-04:00
# 4003953  1485288            502            7107.0 2017-08-01 01:02:00-04:00
# 4003954  1485289            803            7195.0 2017-08-01 01:04:00-04:00
#
#                  Start Station Name  End Station Id                  End Time  \
# 4003950     University Ave / Elm St          7007.0 2017-08-01 01:04:00-04:00
# 4003951  Queen St W / Dovercourt Rd          7046.0 2017-08-01 01:07:00-04:00
# 4003952      Roxton Rd / Harbord St          7128.0 2017-08-01 01:19:00-04:00
# 4003953   Cherry St / Distillery Ln          7067.0 2017-08-01 01:10:00-04:00
# 4003954     Ulster St / Bathurst St          7163.0 2017-08-01 01:17:00-04:00
#
#                    End Station Name User Type
# 4003950       College St / Huron St    Member
# 4003951  Niagara St / Richmond St W    Member
# 4003952       Yonge St / Aylmer Ave    Member
# 4003953       Yonge St / Harbour St    Member
# 4003954          Yonge St / Wood St    Member

# %% [markdown]
# Since the weather data is reported every hour, the time of bike share data can be rounded to the nearest hour.

# %%
# Create a 'Start hour' column to round the starting time to the nearest hour
ridership_clean_hour = ridership_clean.copy()
ridership_clean_hour['Start Hour'] = ridership_clean_hour['Start Time']\
    .apply(lambda row: row.round('60min', ambiguous=True, nonexistent='shift_backward'))

# %%
# Merging the ridership dataset with weather dataset
df_merged = pd.merge(
    ridership_clean_hour, weather_clean,
    left_on="Start Hour",
    right_index=True,
    how="inner",
    sort=False
    )

# %%
df_merged.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14630836 entries, 4003950 to 14291419
# Data columns (total 20 columns):
#  #   Column               Non-Null Count     Dtype
# ---  ------               --------------     -----
#  0   Trip Id              14630836 non-null  int64
#  1   Trip Duration        14630836 non-null  int64
#  2   Start Station Id     14630836 non-null  float64
#  3   Start Time           14630836 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name   14630836 non-null  object
#  5   End Station Id       14630836 non-null  float64
#  6   End Time             14630836 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name     14630836 non-null  object
#  8   User Type            14630836 non-null  object
#  9   Start Hour           14630836 non-null  datetime64[ns, US/Eastern]
#  10  Temp (°C)            14630836 non-null  float64
#  11  Dew Point Temp (°C)  14630836 non-null  float64
#  12  Rel Hum (%)          14630836 non-null  float64
#  13  Precip. Amount (mm)  14630836 non-null  float64
#  14  Wind Dir (10s deg)   14630836 non-null  float64
#  15  Wind Spd (km/h)      14630836 non-null  float64
#  16  Visibility (km)      14630836 non-null  float64
#  17  Hmdx                 4989189 non-null   float64
#  18  Wind Chill           695126 non-null    float64
#  19  Weather              14630836 non-null  object
# dtypes: datetime64[ns, US/Eastern](3), float64(11), int64(2), object(4)
# memory usage: 2.3+ GB

# %%
df_merged.isnull().sum()
# Out:
# Trip Id                       0
# Trip Duration                 0
# Start Station Id              0
# Start Time                    0
# Start Station Name            0
# End Station Id                0
# End Time                      0
# End Station Name              0
# User Type                     0
# Start Hour                    0
# Temp (°C)                     0
# Dew Point Temp (°C)           0
# Rel Hum (%)                   0
# Precip. Amount (mm)           0
# Wind Dir (10s deg)            0
# Wind Spd (km/h)               0
# Visibility (km)               0
# Hmdx                    9641647
# Wind Chill             13935710
# Weather                       0
# dtype: int64

# %%
df_merged.head()
# Out:
#          Trip Id  Trip Duration  Start Station Id                Start Time  \
# 4003950  1485285            290            7004.0 2017-08-01 01:00:00-04:00
# 4003951  1485286            311            7197.0 2017-08-01 01:02:00-04:00
# 4003952  1485287           1053            7196.0 2017-08-01 01:02:00-04:00
# 4003953  1485288            502            7107.0 2017-08-01 01:02:00-04:00
# 4003954  1485289            803            7195.0 2017-08-01 01:04:00-04:00
#
#                  Start Station Name  End Station Id                  End Time  \
# 4003950     University Ave / Elm St          7007.0 2017-08-01 01:04:00-04:00
# 4003951  Queen St W / Dovercourt Rd          7046.0 2017-08-01 01:07:00-04:00
# 4003952      Roxton Rd / Harbord St          7128.0 2017-08-01 01:19:00-04:00
# 4003953   Cherry St / Distillery Ln          7067.0 2017-08-01 01:10:00-04:00
# 4003954     Ulster St / Bathurst St          7163.0 2017-08-01 01:17:00-04:00
#
#                    End Station Name User Type                Start Hour  \
# 4003950       College St / Huron St    Member 2017-08-01 01:00:00-04:00
# 4003951  Niagara St / Richmond St W    Member 2017-08-01 01:00:00-04:00
# 4003952       Yonge St / Aylmer Ave    Member 2017-08-01 01:00:00-04:00
# 4003953       Yonge St / Harbour St    Member 2017-08-01 01:00:00-04:00
# 4003954          Yonge St / Wood St    Member 2017-08-01 01:00:00-04:00
#
#          Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  Precip. Amount (mm)  \
# 4003950       23.0                 17.3         70.0                  0.0
# 4003951       23.0                 17.3         70.0                  0.0
# 4003952       23.0                 17.3         70.0                  0.0
# 4003953       23.0                 17.3         70.0                  0.0
# 4003954       23.0                 17.3         70.0                  0.0
#
#          Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  Hmdx  \
# 4003950                34.0             17.0             16.1  28.0
# 4003951                34.0             17.0             16.1  28.0
# 4003952                34.0             17.0             16.1  28.0
# 4003953                34.0             17.0             16.1  28.0
# 4003954                34.0             17.0             16.1  28.0
#
#          Wind Chill Weather
# 4003950         NaN   Clear
# 4003951         NaN   Clear
# 4003952         NaN   Clear
# 4003953         NaN   Clear
# 4003954         NaN   Clear

# %%
# Write the merged dataframe to csv (Optional step)
# warning! It takes some time to write to csv. My runtime was about 7 min
# path = os.path.join(os.path.abspath(os.getcwd()), 'data')
# df_merged.to_csv(os.path.join(path, 'ridership merged with weather-cleaned.csv'))

# %%
# Merging the df_merged with bikeshare_stations dataset
df_merged_station = pd.merge(
    df_merged, bikeshare_stations,
    left_on='Start Station Id',
    right_on='Station Id',
    how='left',
    sort=False)

df_merged_station.rename({
    'lat' : 'Start lat',
    'lon' : 'Start lon',
    'capacity' : 'Start capacity'
}, axis=1, inplace=True)

df_merged_station.drop(
    ['Station Name', 'Station Id'], 
    axis=1, inplace=True)

df_merged_station = pd.merge(
    df_merged_station, bikeshare_stations,
    left_on='End Station Id',
    right_on='Station Id',
    how='left',
    sort=False)

df_merged_station.rename({
    'lat' : 'End lat',
    'lon' : 'End lon',
    'capacity' : 'End capacity'
}, axis=1, inplace=True)

df_merged_station.drop(
    ['Station Name', 'Station Id'], 
    axis=1, inplace=True)

# %%
df_merged_station.head()
# Out:
#    Trip Id  Trip Duration  Start Station Id                Start Time  \
# 0  1485285            290            7004.0 2017-08-01 01:00:00-04:00
# 1  1485286            311            7197.0 2017-08-01 01:02:00-04:00
# 2  1485287           1053            7196.0 2017-08-01 01:02:00-04:00
# 3  1485288            502            7107.0 2017-08-01 01:02:00-04:00
# 4  1485289            803            7195.0 2017-08-01 01:04:00-04:00
#
#            Start Station Name  End Station Id                  End Time  \
# 0     University Ave / Elm St          7007.0 2017-08-01 01:04:00-04:00
# 1  Queen St W / Dovercourt Rd          7046.0 2017-08-01 01:07:00-04:00
# 2      Roxton Rd / Harbord St          7128.0 2017-08-01 01:19:00-04:00
# 3   Cherry St / Distillery Ln          7067.0 2017-08-01 01:10:00-04:00
# 4     Ulster St / Bathurst St          7163.0 2017-08-01 01:17:00-04:00
#
#              End Station Name User Type                Start Hour  ...  \
# 0       College St / Huron St    Member 2017-08-01 01:00:00-04:00  ...
# 1  Niagara St / Richmond St W    Member 2017-08-01 01:00:00-04:00  ...
# 2       Yonge St / Aylmer Ave    Member 2017-08-01 01:00:00-04:00  ...
# 3       Yonge St / Harbour St    Member 2017-08-01 01:00:00-04:00  ...
# 4          Yonge St / Wood St    Member 2017-08-01 01:00:00-04:00  ...
#
#    Visibility (km)  Hmdx  Wind Chill  Weather  Start lat  Start lon  \
# 0             16.1  28.0         NaN    Clear  43.656518 -79.389099
# 1             16.1  28.0         NaN    Clear  43.643860 -79.422757
# 2             16.1  28.0         NaN    Clear  43.659050 -79.422988
# 3             16.1  28.0         NaN    Clear  43.650279 -79.356832
# 4             16.1  28.0         NaN    Clear  43.660000 -79.408889
#
#    Start capacity    End lat    End lon End capacity
# 0            11.0  43.658148 -79.398167         19.0
# 1            11.0  43.645340 -79.409597         26.0
# 2            11.0  43.675492 -79.388858         15.0
# 3            15.0  43.643795 -79.375413         39.0
# 4            11.0  43.662222 -79.382500         15.0
#
# [5 rows x 26 columns]

# %%
df_merged_station.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14630836 entries, 0 to 14630835
# Data columns (total 26 columns):
#  #   Column               Non-Null Count     Dtype
# ---  ------               --------------     -----
#  0   Trip Id              14630836 non-null  int64
#  1   Trip Duration        14630836 non-null  int64
#  2   Start Station Id     14630836 non-null  float64
#  3   Start Time           14630836 non-null  datetime64[ns, US/Eastern]
#  4   Start Station Name   14630836 non-null  object
#  5   End Station Id       14630836 non-null  float64
#  6   End Time             14630836 non-null  datetime64[ns, US/Eastern]
#  7   End Station Name     14630836 non-null  object
#  8   User Type            14630836 non-null  object
#  9   Start Hour           14630836 non-null  datetime64[ns, US/Eastern]
#  10  Temp (°C)            14630836 non-null  float64
#  11  Dew Point Temp (°C)  14630836 non-null  float64
#  12  Rel Hum (%)          14630836 non-null  float64
#  13  Precip. Amount (mm)  14630836 non-null  float64
#  14  Wind Dir (10s deg)   14630836 non-null  float64
#  15  Wind Spd (km/h)      14630836 non-null  float64
#  16  Visibility (km)      14630836 non-null  float64
#  17  Hmdx                 4989189 non-null   float64
#  18  Wind Chill           695126 non-null    float64
#  19  Weather              14630836 non-null  object
#  20  Start lat            13703178 non-null  float64
#  21  Start lon            13703178 non-null  float64
#  22  Start capacity       13703178 non-null  float64
#  23  End lat              13662804 non-null  float64
#  24  End lon              13662804 non-null  float64
#  25  End capacity         13662804 non-null  float64
# dtypes: datetime64[ns, US/Eastern](3), float64(17), int64(2), object(4)
# memory usage: 2.9+ GB

# %%
# Write the merged dataframe to csv (Optional step)
# warning! It takes some time to write to csv. 
# path = os.path.join(os.path.abspath(os.getcwd()), 'data')
# df_merged_station.to_csv(os.path.join(path, 'All merged-cleaned.csv'))

# %% [markdown]
# **Note**: the cleaned dataframes have NaN values for 'Hmdx' and 'Wind Chill' for natural reasons, and have missing NaN lat, lon, and capacity values for canceled stations. But these stations can be easily filtered out.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Distribution of Trip Duration

# %%
# #Plot Distribution of Trip Duration in sec for each year
# sns.distplot(ridership_2017_clean['Trip Duration'], kde=True, hist=False, color='r', label='2017') 
# sns.distplot(ridership_2018_clean['Trip Duration'], kde=True, hist=False, color='g', label='2018') 
# sns.distplot(ridership_2019_clean['Trip Duration'], kde=True, hist=False, color='black', label='2019') 
# sns.distplot(ridership_2020_clean['Trip Duration'], kde=True, hist=False, color='blue', label='2020') 
# sns.distplot(ridership_2021_clean['Trip Duration'], kde=True, hist=False, color='grey', label='2021') 
# sns.distplot(ridership_2022_clean['Trip Duration'], kde=True, hist=False, color='purple', label='2022') 

# plt.xlabel('Trip Duration (sec)')
# plt.legend()
# plt.xlim(0,2500)
# plt.title('Distribution of Trip Duration in different years')
# plt.show()

# %% [markdown]
# ## 1. How does weather influence the way people use bike-share and ride duration?

# %%
# Aggregate total number of rides by day
df_daily = df_merged.groupby(pd.Grouper(key = "Start Time", freq = "D")).agg({
    'Temp (°C)':'mean',
    'Dew Point Temp (°C)':'mean',
    'Rel Hum (%)':'mean',
    'Precip. Amount (mm)':'mean',
    'Wind Dir (10s deg)':'mean',
    'Wind Spd (km/h)':'mean',
    'Visibility (km)': 'mean',
    'Hmdx': 'mean',
    'Wind Chill': 'mean',
    'Trip Id':'count', 
    'Trip Duration':'mean'}).reset_index()

# Rename the Trip Id to Number of Trips
df_daily.rename(columns={'Trip Id':'Number of Trips'}, inplace=True)

df_daily.head()
# Out:
#                  Start Time  Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# 0 2016-12-31 00:00:00-05:00   1.500000            -3.600000    69.000000
# 1 2017-01-01 00:00:00-05:00   1.874268            -4.402301    63.656904
# 2 2017-01-02 00:00:00-05:00   3.723415             0.920488    82.041463
# 3 2017-01-03 00:00:00-05:00   4.424971             3.959379    96.825086
# 4 2017-01-04 00:00:00-05:00  -2.484864            -7.934218    66.649211
#
#    Precip. Amount (mm)  Wind Dir (10s deg)  Wind Spd (km/h)  Visibility (km)  \
# 0                  0.0           26.000000        39.000000        16.100000
# 1                  0.0           23.768828        19.418410        16.100000
# 2                  0.0            6.821951        22.931707        15.690244
# 3                  0.0            8.330265        14.652474        11.843383
# 4                  0.0           25.714491        46.650646        15.514634
#
#    Hmdx  Wind Chill  Number of Trips  Trip Duration
# 0   NaN         NaN                9     515.222222
# 1   NaN   -6.000000              478     683.410042
# 2   NaN   -2.000000              820     621.463415
# 3   NaN         NaN              869     652.859609
# 4   NaN  -14.923077             1394     621.465567

# %% [markdown]
# ### 1.1 Features with Positive Correlation in terms of Number of Trips and Trip Duration

# %%
fig, axes = plt.subplots(1,4,figsize=(14, 4),sharey=True)

for i, col in enumerate(["Temp (°C)","Dew Point Temp (°C)","Visibility (km)", "Wind Chill"]):
    sns.scatterplot(ax=axes[i],data=df_daily,x=col,y="Number of Trips")

# %%
fig, axes = plt.subplots(1,4,figsize=(14, 4),sharey=True)

for i, col in enumerate(["Temp (°C)","Dew Point Temp (°C)","Visibility (km)", "Wind Chill"]):
    sns.scatterplot(ax=axes[i],data=df_daily,x=col,y="Trip Duration")

# %% [markdown]
# 1.1 A high <b>positive</b> correlation exists between  <b>trip duration and trip duration, and mean temperature, Dew Point Temp, visibility, and wind chill, meaning the warmer the weather, the chiller the wind, and the better visibility</b>, the longer the trips taken.

# %% [markdown]
# ### 1.2 Features with Nagetive Correlation in terms of Number of Trips and Trip Duration

# %%
# Create two scatter plots showing number of rides by wind speed and precipitation
# Negative Correlation
fig, axes = plt.subplots(1,2,figsize=(14, 4),sharey=True)

for i, col in enumerate(["Precip. Amount (mm)","Wind Spd (km/h)"]):
    sns.scatterplot(ax=axes[i],data=df_daily,x=col,y="Trip Duration")

# %%
# Create two scatter plots showing number of rides by wind speed and precipitation
# Negative Correlation
fig, axes = plt.subplots(1,2,figsize=(14, 4),sharey=True)

for i, col in enumerate(["Precip. Amount (mm)","Wind Spd (km/h)"]):
    sns.scatterplot(ax=axes[i],data=df_daily,x=col,y="Number of Trips")

# %% [markdown]
# 1.2 On the other hand, there’s a <b>negetive</b> correlation between <b>trip duration and precipitation as well as wind speed</b>.

# %% [markdown]
# ### 1.3 Features with No Correlation in terms of Number of Trips and Trip Duration

# %%
# Create three scatter plots showing number of rides by Humidity, Wind direction and Hmdx
# No correlation
fig, axes = plt.subplots(1,3,figsize=(14, 4),sharey=True)

for i, col in enumerate(["Rel Hum (%)","Wind Dir (10s deg)","Hmdx"]):
    sns.scatterplot(ax=axes[i],data=df_daily,x=col,y="Number of Trips")

# %%
# Create three scatter plots showing number of rides by Humidity, Wind direction and Hmdx
# No correlation
fig, axes = plt.subplots(1,3,figsize=(14, 4),sharey=True)

for i, col in enumerate(["Rel Hum (%)","Wind Dir (10s deg)","Hmdx"]):
    sns.scatterplot(ax=axes[i],data=df_daily,x=col,y="Trip Duration")

# %% [markdown]
# 1.3 <b>Real Humidity, wind direction and Hmdx</b> have nothing to do with the trip duration (<b>No Correlation</b>).

# %% [markdown]
# ## 2.	What is the difference between user types?

# %%
def isworkday(number):
    if number < 5:
        return True 
    else:
        return False

# %%
# Write your code here
data_days = df_merged.groupby(pd.Grouper(key = "Start Time", freq = "D")).agg(
    ride = ('Start Time','count'),
    duration = ('Trip Duration', 'mean'),
    Temp = ('Temp (°C)','mean'),
    precip = ('Precip. Amount (mm)', 'mean'),
    Member = ('User Type', lambda x: (x == 'Member').sum()),
    Casual = ('User Type', lambda x: (x == 'Casual').sum()),
)
data_days['workday'] = data_days.index.weekday
data_days['workday'] = data_days['workday'].apply(isworkday)

# View DataFrame
data_days.head()
# Out:
#                            ride    duration      Temp  precip  Member  Casual  \
# Start Time
# 2016-12-31 00:00:00-05:00     9  515.222222  1.500000     0.0       9       0
# 2017-01-01 00:00:00-05:00   478  683.410042  1.874268     0.0     410      68
# 2017-01-02 00:00:00-05:00   820  621.463415  3.723415     0.0     752      68
# 2017-01-03 00:00:00-05:00   869  652.859609  4.424971     0.0     852      17
# 2017-01-04 00:00:00-05:00  1394  621.465567 -2.484864     0.0    1360      34
#
#                            workday
# Start Time
# 2016-12-31 00:00:00-05:00    False
# 2017-01-01 00:00:00-05:00    False
# 2017-01-02 00:00:00-05:00     True
# 2017-01-03 00:00:00-05:00     True
# 2017-01-04 00:00:00-05:00     True

# %% [markdown]
# ### 2.1 Comparison of Casual Members and Annual Members on Working and Non-working days

# %%
plt.figure(figsize=(10, 5))

graph = sns.scatterplot(data = data_days, x = "Casual", y = "Member", hue = "workday")

plt.title('Comparison of Casual Members and Annual Members\n on working and Non-working days', fontsize = 18)
plt.xlabel('Casual Members', fontsize = 15)
plt.ylabel('Annul Members', fontsize = 15)
graph.set(xlim=(0))


# show the plot
plt.legend(title = 'workday')
plt.show()

# %% [markdown]
# 2.1 There are more <b>Annual Members</b> using the bikes than <b>Casual Members</b> on <b>working days</b>.

# %% [markdown]
# ### 2.2 Difference of The Number of Trips between Casual Members and Annual Members on Monthly Basis

# %%
def convert_month(month):
    result = []
    for i in month:
        result.append(i.month)
    return result

# %%
# create a month column for the creation of season column
month = list(ridership_clean["Start Time"])
month_list = convert_month(month)
ridership_clean['month'] = month_list

# %%
# create a dataframe based on the month
data_month = df_merged.groupby(pd.Grouper(key = "Start Time", freq = "M")).agg(
    ride = ('Start Time','count'),
    duration = ('Trip Duration', 'mean'),
    Temp = ('Temp (°C)','mean'),
    precip = ('Precip. Amount (mm)', 'mean'),
    Member = ('User Type', lambda x: (x == 'Member').sum()),
    Casual = ('User Type', lambda x: (x == 'Casual').sum()),
)

# View DataFrame
data_month.head()
# Out:
#                             ride    duration      Temp  precip  Member  Casual
# Start Time
# 2016-12-31 00:00:00-05:00      9  515.222222  1.500000     0.0       9       0
# 2017-01-31 00:00:00-05:00  41061  619.606147  0.314220     0.0   39805    1256
# 2017-02-28 00:00:00-05:00  40861  639.822227  1.646864     0.0   38748    2113
# 2017-03-31 00:00:00-04:00  48339  620.697532  1.936621     0.0   46396    1943
# 2017-04-30 00:00:00-04:00  74565  703.113351  9.278521     0.0   63853   10712

# %%
plt.figure(figsize=(10, 5))
plt.title('Average Month rides between Annual Members and Casual Members', fontsize=18)

ax = sns.lineplot(data = data_month, x = data_month.index, y = 'Member', label = 'Annul Members')
ax = sns.lineplot(data = data_month, x = data_month.index, y = 'Casual', label = 'Casual Members')

ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Time', fontsize=14)
ax.set_ylabel('Number of rides', fontsize=14)

plt.legend(loc='upper left')
plt.show()

# %%
import re
# plot the graph of Average Month rides between Annual Members and Casual Members
def df_duration_generator(df):
    df = df.groupby(pd.Grouper(key = "Start Time", freq = "M")).agg(
        ride = ('Start Time','count'),
        Member = ('User Type', lambda x: (x == 'Member').sum()),
        Casual = ('User Type', lambda x: (x == 'Casual').sum()),
    )
    

    plt.figure(figsize=(10, 5))
    plt.title('Average Month rides between Annual Members and Casual Members', fontsize=18)

    ax = sns.lineplot(data = df, x = df.index, y = 'Member', label = 'Annul Members')
    ax = sns.lineplot(data = df, x = df.index, y = 'Casual', label = 'Casual Members')

    ax.xaxis.set_tick_params(labelsize=14)
    ax.yaxis.set_tick_params(labelsize=14)
    ax.set_xlabel('Time', fontsize=14)
    ax.set_ylabel('Number of rides', fontsize=14)

    plt.legend(loc='upper left')
    plt.show()

# %%
# plot the closeup graph for each year
ridership_clean_list = [
    ridership_2017_clean,
    ridership_2018_clean,
    ridership_2019_clean,
    ridership_2020_clean,
    ridership_2021_clean,
    ridership_2022_clean
]
for i in ridership_clean_list:
    df_duration_generator(i)

# %% [markdown]
# 2.2 From year 2017 to 2021, the monthly number of trips of <b>Annual Members</b> is always more than <b>Casual Members </b>. However, in the year of 2022, there is an increasing number of trips made by <b>Casual Members</b>, which exceeds <b>Casual  Members</b>.

# %% [markdown]
# ### 2.3 The Trips Duration between Casual Members and Annual Members on Monthly Basis

# %%
# Plot box pots and density plots to depict distribution of Trip Distance and Trip Duration by user type.
# it takes a little bit longer to run
fig, (ax1,ax2) = plt.subplots(2,2,figsize=(12,8))
for i, var in enumerate(['Trip Duration','month']):
    for j,user in enumerate(ridership_clean['User Type'].unique()):
        sns.distplot(ridership_clean[ridership_clean['User Type'] == user][var],hist=False,ax=ax2[i]) 
        sns.boxplot(x=var, y="User Type",data=ridership_clean, ax=ax1[i]).set(xlabel="",ylabel="")

# %% [markdown]
# 2.3 Annual members tend to take shorter rides compared to casual members who take longer rides but also travel slightly longer distances as well.

# %% [markdown]
# ## 3. What are the effects of difference seasons and time of the day on the frequencies of rides and duration?

# %%
# assign the season to the month
def season(num):
    if num >= 3 and num < 6:
        return "Spring"
    elif num >= 6 and num < 9:
        return "Summer"
    elif num >= 9 and num < 11:
        return "Fall"
    else:
        return "Winter"

# %%
data_month["season"] = data_month.index.month
data_month['season'] = data_month['season'].apply(season)
data_month.head()
# Out:
#                             ride    duration      Temp  precip  Member  \
# Start Time
# 2016-12-31 00:00:00-05:00      9  515.222222  1.500000     0.0       9
# 2017-01-31 00:00:00-05:00  41061  619.606147  0.314220     0.0   39805
# 2017-02-28 00:00:00-05:00  40861  639.822227  1.646864     0.0   38748
# 2017-03-31 00:00:00-04:00  48339  620.697532  1.936621     0.0   46396
# 2017-04-30 00:00:00-04:00  74565  703.113351  9.278521     0.0   63853
#
#                            Casual  season
# Start Time
# 2016-12-31 00:00:00-05:00       0  Winter
# 2017-01-31 00:00:00-05:00    1256  Winter
# 2017-02-28 00:00:00-05:00    2113  Winter
# 2017-03-31 00:00:00-04:00    1943  Spring
# 2017-04-30 00:00:00-04:00   10712  Spring

# %% [markdown]
# ### 3.1 Season vs. Number of Rides

# %%
plt.figure(figsize=(10, 5))
plt.title('Season vs. Number of Rides', fontsize=18)

# plot the graph
graph = sns.violinplot(data = data_month, x = "season", y = 'ride')

# set labels
plt.xlabel('Season', fontsize = 15)
plt.ylabel('Rides per Day', fontsize = 15)
graph.set(ylim=(0))

# show the plot
plt.show()

# %% [markdown]
# 3.1 There are more rides in the <b>Summer and Spring </b> whereas fewer rides in <b>Fall and Winter</b>.

# %% [markdown]
# ### 3.2 Season vs. Ride Duration

# %%
plt.figure(figsize=(10, 5))
plt.title('Season vs. Rides Duration', fontsize=18)

# plot the graph
graph = sns.violinplot(data = data_month, x = "season", y = 'duration')

# set labels
plt.xlabel('Season', fontsize = 15)
plt.ylabel('Rides Duration', fontsize = 15)
graph.set(ylim=(400))

# show the plot
plt.show()

# %% [markdown]
# 3.2 During <b>Summer and Fall </b> time, users tend to ride long than <b>Winter and Spring time</b>.

# %% [markdown]
# ## 4. Are there popular route differences in seasons?

# %% [markdown]
# ### 4.0 The Top 5 most popular route of all time

# %%
# len(start) = len(end)
def Route(start, end):
    result = []
    temp = 0
    for i in range(len(start)):
        temp = str(int(start[i])) + '-' + str(int(end[i]))
        result.append(temp)
    return result

# %%
# create a RouteID list
# put RouteID list into df_merged as a new column
start = list(ridership_clean['Start Station Id'])
end = list(ridership_clean['End Station Id'])

# combine the start stations and end stations together to form a RouteIDs
RouteID = Route(start, end)
ridership_clean['RouteID'] = RouteID

# %%
# find the top 5 most popular routes
def pop_routes(df):
    df = df.groupby("RouteID").agg({"Start Station Name":"max",
                                                  "End Station Name":"max",
                                                  "Trip Id":"count"}).reset_index()

    df.rename(columns = {'Trip Id':'Number of Trips'}, inplace = True)
    df = df.sort_values("Number of Trips",ascending=False)
    df = df.reset_index()
    return df

# %%
# create a dataframe with the top 5 most popular routes
pop_routes_df = pop_routes(ridership_clean)

# Create a dataframe depicting the 5 most popular routes
pop_routes_df.head()
# Out:
#     index    RouteID                             Start Station Name  \
# 0   77715  7171-7171          Ontario Place Blvd / Lakeshore Blvd W
# 1  146550  7354-7354       Tommy Thompson Park (Leslie Street Spit)
# 2   79400  7175-7175                       HTO Park (Queens Quay W)
# 3  142944  7344-7354                                   Cherry Beach
# 4   89819  7203-7076  Bathurst St/Queens Quay(Billy Bishop Airport)
#
#                            End Station Name  Number of Trips
# 0     Ontario Place Blvd / Lakeshore Blvd W            11895
# 1  Tommy Thompson Park (Leslie Street Spit)            11472
# 2                  HTO Park (Queens Quay W)             8971
# 3  Tommy Thompson Park (Leslie Street Spit)             8567
# 4                   York St / Queens Quay W             8008

# %% [markdown]
# 4.0 The top 5 most popular routes are:
#
#     1) Ontario Place Blvd / Lakeshore Blvd W - Ontario Place Blvd / Lakeshore Blvd W
#     2) Tommy Thompson Park (Leslie Street Spit)	- Tommy Thompson Park (Leslie Street Spit)
#     3）HTO Park (Queens Quay W) - HTO Park (Queens Quay W)
#     4）Cherry Beach - Tommy Thompson Park (Leslie Street Spit)
#     5）Bathurst St/Queens Quay(Billy Bishop Airport)	- York St / Queens Quay W
#
# The start stations and end stations of the first three routes are the same, meaning these places(parks) are popular for bikers. All of these places are parks or places suitable for biking.

# %% [markdown]
# ### 4.1 The Top 5 most popular route in different seasons

# %%
# create a season column based on the month column
ridership_clean['season'] = ridership_clean['month'].apply(season)

# %% [markdown]
# #### 4.1.1 The Top 5 most popular route in Summer

# %%
# dataframe of the season of summer
summer = ridership_clean[ridership_clean.season == 'Summer']

# %%
pop_routes_summer = pop_routes(summer)

# Create a dataframe depicting the 5 most popular routes
pop_routes_summer.head()
# Out:
#     index    RouteID                        Start Station Name  \
# 0   72748  7171-7171     Ontario Place Blvd / Lakeshore Blvd W
# 1  135976  7354-7354  Tommy Thompson Park (Leslie Street Spit)
# 2   74319  7175-7175                  HTO Park (Queens Quay W)
# 3  132839  7344-7354                              Cherry Beach
# 4  117033  7288-7288               Humber Bay Shores Park West
#
#                            End Station Name  Number of Trips
# 0     Ontario Place Blvd / Lakeshore Blvd W             6923
# 1  Tommy Thompson Park (Leslie Street Spit)             6502
# 2                  HTO Park (Queens Quay W)             5589
# 3  Tommy Thompson Park (Leslie Street Spit)             4629
# 4               Humber Bay Shores Park West             4360

# %% [markdown]
# 4.1.1 The top 5 most popular routes in summer are:
#
#     1) Ontario Place Blvd / Lakeshore Blvd W - Ontario Place Blvd / Lakeshore Blvd W
#     2) Tommy Thompson Park (Leslie Street Spit)	- Tommy Thompson Park (Leslie Street Spit)
#     3）HTO Park (Queens Quay W) - HTO Park (Queens Quay W)
#     4）Cherry Beach - Tommy Thompson Park (Leslie Street Spit)
#     5）Humber Bay Shores Park West - Humber Bay Shores Park West

# %% [markdown]
# #### 4.1.2 The Top 5 most popular route in Fall

# %%
fall = ridership_clean[ridership_clean.season == 'Fall']

# %%
pop_routes_fall = pop_routes(fall)

# Create a dataframe depicting the 5 most popular routes
pop_routes_fall.head()
# Out:
#     index    RouteID                             Start Station Name  \
# 0   60774  7171-7171          Ontario Place Blvd / Lakeshore Blvd W
# 1  111507  7354-7354       Tommy Thompson Park (Leslie Street Spit)
# 2   24204  7059-7033                     Front St W / Blue Jays Way
# 3   69946  7203-7076  Bathurst St/Queens Quay(Billy Bishop Airport)
# 4   30725  7076-7203                        York St / Queens Quay W
#
#                                 End Station Name  Number of Trips
# 0          Ontario Place Blvd / Lakeshore Blvd W             1813
# 1       Tommy Thompson Park (Leslie Street Spit)             1712
# 2                                  Union Station             1481
# 3                        York St / Queens Quay W             1426
# 4  Bathurst St/Queens Quay(Billy Bishop Airport)             1397

# %% [markdown]
# 4.1.2 The top 5 most popular routes in fall are:
#
#     1) Ontario Place Blvd / Lakeshore Blvd W - Ontario Place Blvd / Lakeshore Blvd W
#     2) Tommy Thompson Park (Leslie Street Spit)	- Tommy Thompson Park (Leslie Street Spit)
#     3）Front St W / Blue Jays Way - Union Station
#     4）Bathurst St/Queens Quay(Billy Bishop Airport) - York St / Queens Quay W
#     5）Cherry Beach - Tommy Thompson Park (Leslie Street Spit)

# %% [markdown]
# #### 4.1.3 The Top 5 most popular route in Winter

# %%
winter = ridership_clean[ridership_clean.season == 'Winter']

# %%
pop_routes_winter = pop_routes(winter)

# Create a dataframe depicting the 5 most popular routes
pop_routes_winter.head()
# Out:
#    index    RouteID                             Start Station Name  \
# 0  22058  7059-7033                     Front St W / Blue Jays Way
# 1  61524  7203-7076  Bathurst St/Queens Quay(Billy Bishop Airport)
# 2  27862  7076-7203                        York St / Queens Quay W
# 3  54144  7173-7179                         Cariboo St / Rail Path
# 4    924  7002-7250                     St. George St / Bloor St W
#
#                                 End Station Name  Number of Trips
# 0                                  Union Station             1752
# 1                        York St / Queens Quay W              892
# 2  Bathurst St/Queens Quay(Billy Bishop Airport)              816
# 3      Bloor GO / UP Station/ Rail Path_canceled              722
# 4             St. George St / Russell St - SMART              713

# %% [markdown]
# 4.1.3 The top 5 most popular routes in winter are:
#     1) Front St W / Blue Jays Way - Union Station
#     2) Tommy Thompson Park (Leslie Street Spit) - Tommy Thompson Park (Leslie Street Spit)
#     3）Ontario Place Blvd / Lakeshore Blvd W - Ontario Place Blvd / Lakeshore Blvd W
#     4）Bathurst St/Queens Quay(Billy Bishop Airport)	 - York St / Queens Quay W
#     5）York St / Queens Quay W - Bathurst St/Queens Quay(Billy Bishop Airport)

# %% [markdown]
# #### 4.1.4 The Top 5 most popular route in Spring

# %%
spring = ridership_clean[ridership_clean.season == 'Spring']

# %%
pop_routes_spring = pop_routes(spring)

# Create a dataframe depicting the 5 most popular routes
pop_routes_spring.head()
# Out:
#     index    RouteID                        Start Station Name  \
# 0  113107  7354-7354  Tommy Thompson Park (Leslie Street Spit)
# 1   61714  7171-7171     Ontario Place Blvd / Lakeshore Blvd W
# 2  110818  7344-7354                              Cherry Beach
# 3   98414  7288-7288               Humber Bay Shores Park West
# 4   62997  7175-7175                  HTO Park (Queens Quay W)
#
#                            End Station Name  Number of Trips
# 0  Tommy Thompson Park (Leslie Street Spit)             2820
# 1     Ontario Place Blvd / Lakeshore Blvd W             2750
# 2  Tommy Thompson Park (Leslie Street Spit)             2210
# 3               Humber Bay Shores Park West             2109
# 4                  HTO Park (Queens Quay W)             2035

# %% [markdown]
# 4.1.3 The top 5 most popular routes in spring are:
#     1) Ontario Place Blvd / Lakeshore Blvd W - Ontario Place Blvd / Lakeshore Blvd W
#     2) Tommy Thompson Park (Leslie Street Spit) - Tommy Thompson Park (Leslie Street Spit)
#     3）Cherry Beach - Tommy Thompson Park (Leslie Street Spit)
#     4）HTO Park (Queens Quay W) - HTO Park (Queens Quay W)
#     5）Humber Bay Shores Park West - Humber Bay Shores Park West

# %% [markdown]
# ### 4.2 The Top 5 most popular route for Annual Members

# %%
#Subset dataframe to include only Casual Members and groupby R›oute ID.
def pop_route_user_type(df, feature, member):
    result_df = df[df[feature] == member].groupby("RouteID").agg({"Start Station Name":"max",
                                                  "End Station Name":"max",                                     
                                                  "Trip Id":"count"}).reset_index()
                        
    result_df.rename(columns = {'Trip Id':'Number of Trips'}, inplace = True)
    result_df= result_df.sort_values("Number of Trips",ascending=False)
    #Sort by Number of Trips
    return result_df

# %%
annual_member_df = pop_route_user_type(ridership_clean, 'User Type', 'Member')

# %%
annual_member_df.head()
# Out:
#           RouteID                             Start Station Name  \
# 27870   7059-7033                     Front St W / Blue Jays Way
# 83469   7203-7076  Bathurst St/Queens Quay(Billy Bishop Airport)
# 35523   7076-7203                        York St / Queens Quay W
# 135062  7354-7354       Tommy Thompson Park (Leslie Street Spit)
# 24270   7051-7042     Wellesley St E / Yonge St Green P_canceled
#
#                                      End Station Name  Number of Trips
# 27870                                   Union Station             7033
# 83469                         York St / Queens Quay W             4935
# 35523   Bathurst St/Queens Quay(Billy Bishop Airport)             4347
# 135062       Tommy Thompson Park (Leslie Street Spit)             3359
# 24270                  Sherbourne St / Wellesley St E             3296

# %% [markdown]
# 4.2 The top 5 most popular routes in for Annual Members are:
#
#     1) Front St W / Blue Jays Way - Union Station
#     2) Bathurst St/Queens Quay(Billy Bishop Airport) - York St / Queens Quay W
#     3）York St / Queens Quay W - Bathurst St/Queens Quay(Billy Bishop Airport)
#     4）Tommy Thompson Park (Leslie Street Spit) - Tommy Thompson Park (Leslie Street Spit)
#     5）Wellesley St E / Yonge St Green P_canceled - Sherbourne St / Wellesley St E

# %% [markdown]
# ### 4.3 The Top 5 most popular route for Casual Members

# %%
casual_member_df = annual_member_df = pop_route_user_type(ridership_clean, 'User Type', 'Casual')
casual_member_df.head()
# Out:
#           RouteID                        Start Station Name  \
# 69906   7171-7171     Ontario Place Blvd / Lakeshore Blvd W
# 130217  7354-7354  Tommy Thompson Park (Leslie Street Spit)
# 71411   7175-7175                  HTO Park (Queens Quay W)
# 112236  7288-7288               Humber Bay Shores Park West
# 93503   7242-7242             Lakeshore Blvd W / Ontario Dr
#
#                                 End Station Name  Number of Trips
# 69906      Ontario Place Blvd / Lakeshore Blvd W             8796
# 130217  Tommy Thompson Park (Leslie Street Spit)             8113
# 71411                   HTO Park (Queens Quay W)             7573
# 112236               Humber Bay Shores Park West             6220
# 93503              Lakeshore Blvd W / Ontario Dr             5735

# %% [markdown]
# 4.3 The top 5 most popular routes in for Casual Members are:
#
#     1) Ontario Place Blvd / Lakeshore Blvd W - Ontario Place Blvd / Lakeshore Blvd W
#     2) Tommy Thompson Park (Leslie Street Spit) - Tommy Thompson Park (Leslie Street Spit)
#     3）HTO Park (Queens Quay W) - HTO Park (Queens Quay W)
#     4）Humber Bay Shores Park West - Humber Bay Shores Park West
#     5）Lakeshore Blvd W / Ontario Dr - Lakeshore Blvd W / Ontario Dr

# %% [markdown]
# ## 5. What is the impact of major social changes? Special occasions such as the pandemic or the introduction of e-bikes.

# %% [markdown]
# ### 5.1 Number of Rides and Ride Duration per Year

# %%
# create a dataframe based on the month
data_year = ridership_clean.groupby(pd.Grouper(key = "Start Time", freq = "Y")).agg(
    ride = ('Start Time','count'),
    duration = ('Trip Duration', 'mean')
)
data_year.index = data_year.index.year

# View DataFrame
data_year.head()
# Out:
#                ride    duration
# Start Time
# 2016             58  577.396552
# 2017        1345412  714.297991
# 2018        1826363  728.516352
# 2019        2329015  757.139532
# 2020        2785379  872.845455

# %%
data_year = data_year.drop(2016)

# %%
# figure size
plt.figure(figsize=(10, 5))
plt.title('Number of Rides per Year', fontsize=18)

# plot the graph
ax = sns.barplot(data=data_year, x = data_year.index, y = 'ride')

# set x-axis amd y-axis
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Average Rides per Year(in Million)', fontsize=14)

# show plot
plt.show()

# %%
# figure size
plt.figure(figsize=(10, 5))
plt.title('Rides Duration per Year', fontsize=18)

# plot the graph
ax = sns.barplot(data=data_year, x = data_year.index, y = 'duration')

# set x-axis amd y-axis
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Year', fontsize=14)
ax.set_ylabel('Average Duration per Year', fontsize=14)

# show plot
plt.show()

# %% [markdown]
# 5.1 There is <b>no</b> differece of <b>number of rides</b> and <b>ride duration</b> between <b>before</b> and <b>during pandemic</b>.

# %% [markdown]
# ### 5.2 Top 5 Busiest Start Stations — Before Pandemic

# %%
# create two dataframs of before pandemic and during

ridership_before_pandemic = pd.concat([
    ridership_2017_clean,
    ridership_2018_clean,
])

ridership_during_pandemic = pd.concat([
    ridership_2019_clean,
    ridership_2020_clean,
    ridership_2021_clean,
    ridership_2022_clean

])

# %%
def five_busiest_stations(dataframe):
    return dataframe.value_counts().head().reset_index()\
            .rename(columns={"index":"Start Station","Start Station Name":"Number of Trips"})

# %%
busieststations_before_pandemic = five_busiest_stations(ridership_before_pandemic["Start Station Name"])
busieststations_before_pandemic.head()
# Out:
#                      Start Station  Number of Trips
# 0                    Union Station            39710
# 1          Bay St / Wellesley St W            36187
# 2          York St / Queens Quay W            35477
# 3  Simcoe St / Wellington St South            34965
# 4           Dundas St W / Yonge St            34661

# %% [markdown]
# 5.2 The top 5 most busiest stations in before pandemic are:
#
#     1) Union Station
#     2) Bay St / Wellesley St W
#     3）York St / Queens Quay W
#     4）Simcoe St / Wellington St South
#     5）Dundas St W / Yonge St

# %% [markdown]
# ### 5.3 Top 5 Busiest Start Stations — During Pandemic

# %%
busieststations_during_pandemic = five_busiest_stations(ridership_during_pandemic["Start Station Name"])
busieststations_during_pandemic.head()
# Out:
#                                    Start Station  Number of Trips
# 0                        York St / Queens Quay W           109966
# 1                 Lake Shore Blvd W / Ontario Dr            88294
# 2            Queens Quay E / Lower Sherbourne St            84039
# 3        Bay St / Queens Quay W (Ferry Terminal)            83727
# 4  Ontario Place Blvd / Lake Shore Blvd W (East)            82109

# %% [markdown]
# 5.3 The top 5 most busiest stations in during pandemic are:
#
#     1) York St / Queens Quay W
#     2) Lake Shore Blvd W / Ontario Dr
#     3）Queens Quay E / Lower Sherbourne St
#     4）Bay St / Queens Quay W (Ferry Terminal)
#     5）Ontario Place Blvd / Lake Shore Blvd W (East)

# %% [markdown]
# # ML Model

# %% [markdown]
# # Conclusions
